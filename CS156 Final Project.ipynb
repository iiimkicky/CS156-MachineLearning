# %%
import codecs
import glob
import logging
import multiprocessing
import os
import pprint
import re

import gensim.models.word2vec as w2v
from gensim.models import Phrases
import gensim.models
import gensim.models.keyedvectors as kv
import sklearn.manifold
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# ### 1. Prepare the data

# %%
import nltk
from nltk.corpus import stopwords 
from nltk.stem.wordnet import WordNetLemmatizer
import string
#nltk.download('stopwords')
#nltk.download('wordnet')
f = open("The Handmaid's Tale - Margaret Atwood.txt",'r')
book = [f.read().decode('utf-8')]

# %%
#set up loggin
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
#split the text into sentences
tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')
raw_sentences = tokenizer.tokenize(book[0])

#transform the sentence in a list
def to_wordlist(raw_sentences):
    clean = re.sub("[^a-zA-Z]"," ", raw_sentences)
    words = clean.split()
    return words
raw_wordlist = [to_wordlist(i) for i in raw_sentences_cleaned]

#the length of these wordlists stays the same as len(raw_sentence)
if len(raw_wordlist) == len(raw_sentences):
    print True
# Out:
# True

# %%
#remove stopwords 
stop = set(stopwords.words('english'))
#add a few more stopwords mannully after examining the results
stop.update(('something','almost','already','just','could','still','though'))

exclude = set(string.punctuation)
#punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
sentences = [] 
for s in raw_wordlist:
    s = [w for w in s if not w in stop]
    wl = ''.join(ch for ch in s if ch not in exclude)
    sentences.append(s)

#check if the operations yield the rigth results
print "raw sentence>> ", raw_sentences[37]
print "split into words>> ", raw_wordlist[37]       
print "with stopwords removed>> ", sentences[37]
# Out:
# raw sentence>>  When the window is partly open—it only opens partly—the air can come in and make the curtains move.
# split into words>>  [u'window', u'partly', u'open', u'it', u'open', u'partly', u'the', u'air', u'come', u'make', u'curtain', u'move']
# with stopwords removed>>  [u'window', u'partly', u'open', u'open', u'partly', u'air', u'come', u'make', u'curtain', u'move']

# %%
token_count = sum([len(sentences) for sentence in sentences])
print"The book corpus contains {0:,} tokens".format(token_count)
# Out:
# The book corpus contains 65,593,801 tokens

# %% [markdown]
# ### 2.Train the model
#
# There are 3 main tasks that word vectors can be useful for calculating: Distance, Similarity and Ranking
#
# Num_features: the dimension of the word vectors - the more features a vector has the more accurate it is but also means more computational complexity

# %%
###Create the word vector representations

#the dimension of the vector
num_features = 300
#minimum word count for a word to be considered
min_word_count = 7

# the number of words that preceed or follow a word -- these words are what we consider as "context" 
context_size = 7

#threshold for configuring which higher-frequency words are randomly downsampled (source: genism documentation)
downsample = 1e-3

#Number of worker threads to train the model (more threads, higher speed)
#the cpu_count returns the number of CPUs in the system
num_workers = multiprocessing.cpu_count() 

#To make the results reproducible and debugging easier
seed = 10

# %%
w2vmodel = w2v.Word2Vec(sentences=sentences,
    sg=1, #algorithm: skip-gram
    seed=seed,#random no. generator
    workers=num_workers, #number of worker threads
    size=num_features, #dimensions of word vectors
    min_count=min_word_count,#minimun occurences words
    window=context_size,#size of "context" around a word
    sample=downsample, #downsample setting
    #negative = 10 #negative sampling 
)
# Out:
# 2017-12-14 18:39:08,652 : INFO : collecting all words and their counts
# 2017-12-14 18:39:08,656 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2017-12-14 18:39:08,699 : INFO : collected 8312 word types from a corpus of 43479 raw words and 8099 sentences
# 2017-12-14 18:39:08,702 : INFO : Loading a fresh vocabulary
# 2017-12-14 18:39:08,719 : INFO : min_count=7 retains 1152 unique words (13% of original 8312, drops 7160)
# 2017-12-14 18:39:08,723 : INFO : min_count=7 leaves 30647 word corpus (70% of original 43479, drops 12832)
# 2017-12-14 18:39:08,734 : INFO : deleting the raw counts dictionary of 8312 items
# 2017-12-14 18:39:08,738 : INFO : sample=0.001 downsamples 67 most-common words
# 2017-12-14 18:39:08,742 : INFO : downsampling leaves estimated 26501 word corpus (86.5% of prior 30647)
# 2017-12-14 18:39:08,746 : INFO : estimated required memory for 1152 words and 300 dimensions: 3340800 bytes
# 2017-12-14 18:39:08,757 : INFO : resetting layer weights
# 2017-12-14 18:39:08,807 : INFO : training model with 4 workers on 1152 vocabulary and 300 features, using sg=1 hs=0 sample=0.001 negative=5 window=7
# 2017-12-14 18:39:09,297 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2017-12-14 18:39:09,303 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2017-12-14 18:39:09,314 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2017-12-14 18:39:09,323 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2017-12-14 18:39:09,326 : INFO : training on 217395 raw words (132482 effective words) took 0.4s, 307902 effective words/s
# 2017-12-14 18:39:09,328 : WARNING : under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay

# %%
w2vmodel.build_vocab(sentences,update=True)
w2vmodel.wv.vocab
# Out:
# 2017-12-14 18:39:10,220 : INFO : collecting all words and their counts
# 2017-12-14 18:39:10,223 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2017-12-14 18:39:10,258 : INFO : collected 8312 word types from a corpus of 43479 raw words and 8099 sentences
# 2017-12-14 18:39:10,261 : INFO : Updating model with new vocabulary
# 2017-12-14 18:39:10,277 : INFO : New added 1152 unique words (12% of original 9464) and increased the count of 1152 pre-existing words (12% of original 9464)
# 2017-12-14 18:39:10,294 : INFO : deleting the raw counts dictionary of 8312 items
# 2017-12-14 18:39:10,296 : INFO : sample=0.001 downsamples 134 most-common words
# 2017-12-14 18:39:10,298 : INFO : downsampling leaves estimated 53002 word corpus (172.9% of prior 30647)
# 2017-12-14 18:39:10,301 : INFO : estimated required memory for 2304 words and 300 dimensions: 6681600 bytes
# 2017-12-14 18:39:10,308 : INFO : updating layer weights
# {u'salvagings': <gensim.models.keyedvectors.Vocab at 0x11fc55810>,
#  u'forget': <gensim.models.keyedvectors.Vocab at 0x11fc4e050>,
#  u'chain': <gensim.models.keyedvectors.Vocab at 0x11f403410>,
#  u'forbidden': <gensim.models.keyedvectors.Vocab at 0x11fc4e090>,
#  u'wreath': <gensim.models.keyedvectors.Vocab at 0x11f49cc10>,
#  u'bear': <gensim.models.keyedvectors.Vocab at 0x11fc60690>,
#  u'yellow': <gensim.models.keyedvectors.Vocab at 0x1102e3410>,
#  u'month': <gensim.models.keyedvectors.Vocab at 0x11f4bde10>,
#  u'four': <gensim.models.keyedvectors.Vocab at 0x11f156c10>,
#  u'known': <gensim.models.keyedvectors.Vocab at 0x11fc72650>,
#  u'sleep': <gensim.models.keyedvectors.Vocab at 0x11fc60e90>,
#  u'ice': <gensim.models.keyedvectors.Vocab at 0x11fc68f50>,
#  u'hanging': <gensim.models.keyedvectors.Vocab at 0x11f685990>,
#  u'go': <gensim.models.keyedvectors.Vocab at 0x11fbc5250>,
#  u'chair': <gensim.models.keyedvectors.Vocab at 0x11f403490>,
#  u'milk': <gensim.models.keyedvectors.Vocab at 0x11fb9f850>,
#  u'seemed': <gensim.models.keyedvectors.Vocab at 0x11f3cf990>,
#  u'whose': <gensim.models.keyedvectors.Vocab at 0x11fb99250>,
#  u'hurry': <gensim.models.keyedvectors.Vocab at 0x11fc60a90>,
#  u'tv': <gensim.models.keyedvectors.Vocab at 0x11f3e4590>,
#  u'elizabeth': <gensim.models.keyedvectors.Vocab at 0x11fc68410>,
#  u'flash': <gensim.models.keyedvectors.Vocab at 0x11f499b10>,
#  u'grass': <gensim.models.keyedvectors.Vocab at 0x11fc721d0>,
#  u'young': <gensim.models.keyedvectors.Vocab at 0x11f3cf9d0>,
#  u'send': <gensim.models.keyedvectors.Vocab at 0x11f3cfa10>,
#  u'suits': <gensim.models.keyedvectors.Vocab at 0x11fc4e250>,
#  u'finally': <gensim.models.keyedvectors.Vocab at 0x11fb9f890>,
#  u'waterford': <gensim.models.keyedvectors.Vocab at 0x11fc60210>,
#  u'lord': <gensim.models.keyedvectors.Vocab at 0x11f6856d0>,
#  u'sorry': <gensim.models.keyedvectors.Vocab at 0x11fb99290>,
#  u'te': <gensim.models.keyedvectors.Vocab at 0x11f3e4610>,
#  u'waiting': <gensim.models.keyedvectors.Vocab at 0x11fc5c390>,
#  u'sent': <gensim.models.keyedvectors.Vocab at 0x11f3cfa50>,
#  u'carried': <gensim.models.keyedvectors.Vocab at 0x11fc4f210>,
#  u'washroom': <gensim.models.keyedvectors.Vocab at 0x11f4bde50>,
#  u'brown': <gensim.models.keyedvectors.Vocab at 0x11f499b50>,
#  u'lack': <gensim.models.keyedvectors.Vocab at 0x11fc722d0>,
#  u'garden': <gensim.models.keyedvectors.Vocab at 0x11f3cfa90>,
#  u'sitting': <gensim.models.keyedvectors.Vocab at 0x11fc68390>,
#  u'far': <gensim.models.keyedvectors.Vocab at 0x11fc723d0>,
#  u'blanket': <gensim.models.keyedvectors.Vocab at 0x11f49cc50>,
#  u'none': <gensim.models.keyedvectors.Vocab at 0x11fc4e310>,
#  u'fat': <gensim.models.keyedvectors.Vocab at 0x11fc72410>,
#  u'choice': <gensim.models.keyedvectors.Vocab at 0x11f4034d0>,
#  u'every': <gensim.models.keyedvectors.Vocab at 0x11fc60f10>,
#  u'fall': <gensim.models.keyedvectors.Vocab at 0x11fc4e0d0>,
#  u'telling': <gensim.models.keyedvectors.Vocab at 0x11fbc5310>,
#  u'trouble': <gensim.models.keyedvectors.Vocab at 0x11f499b90>,
#  u'difference': <gensim.models.keyedvectors.Vocab at 0x11fc4e110>,
#  u'fireplace': <gensim.models.keyedvectors.Vocab at 0x11fc60f50>,
#  u'wipe': <gensim.models.keyedvectors.Vocab at 0x11f3cfad0>,
#  u'minute': <gensim.models.keyedvectors.Vocab at 0x11f403510>,
#  u'school': <gensim.models.keyedvectors.Vocab at 0x11fc60f90>,
#  u'went': <gensim.models.keyedvectors.Vocab at 0x11fb99890>,
#  u'stiff': <gensim.models.keyedvectors.Vocab at 0x11fbc5350>,
#  u'wooden': <gensim.models.keyedvectors.Vocab at 0x11f685590>,
#  u'killed': <gensim.models.keyedvectors.Vocab at 0x11fbc5e10>,
#  u'list': <gensim.models.keyedvectors.Vocab at 0x11fc72490>,
#  u'leave': <gensim.models.keyedvectors.Vocab at 0x11f403590>,
#  u'married': <gensim.models.keyedvectors.Vocab at 0x11fc5cb10>,
#  u'small': <gensim.models.keyedvectors.Vocab at 0x11f3e4690>,
#  u'sidewalk': <gensim.models.keyedvectors.Vocab at 0x11f499bd0>,
#  u'round': <gensim.models.keyedvectors.Vocab at 0x11fb9f910>,
#  u'clothes': <gensim.models.keyedvectors.Vocab at 0x11fb992d0>,
#  u'enjoy': <gensim.models.keyedvectors.Vocab at 0x11fc60fd0>,
#  u'upper': <gensim.models.keyedvectors.Vocab at 0x11fc729d0>,
#  u'work': <gensim.models.keyedvectors.Vocab at 0x11f49ced0>,
#  u'force': <gensim.models.keyedvectors.Vocab at 0x11fb99310>,
#  u'ten': <gensim.models.keyedvectors.Vocab at 0x11fc724d0>,
#  u'tired': <gensim.models.keyedvectors.Vocab at 0x11f6857d0>,
#  u'sigh': <gensim.models.keyedvectors.Vocab at 0x11f4035d0>,
#  u'skin': <gensim.models.keyedvectors.Vocab at 0x11fb9f810>,
#  u'sign': <gensim.models.keyedvectors.Vocab at 0x11f403610>,
#  u'past': <gensim.models.keyedvectors.Vocab at 0x11f3e46d0>,
#  u'fold': <gensim.models.keyedvectors.Vocab at 0x11fc5c350>,
#  u'second': <gensim.models.keyedvectors.Vocab at 0x11f685710>,
#  u'street': <gensim.models.keyedvectors.Vocab at 0x11fc68050>,
#  u'dried': <gensim.models.keyedvectors.Vocab at 0x11fc55450>,
#  u'pass': <gensim.models.keyedvectors.Vocab at 0x11f3e4710>,
#  u'eating': <gensim.models.keyedvectors.Vocab at 0x11fbc5410>,
#  u'judd': <gensim.models.keyedvectors.Vocab at 0x11fc555d0>,
#  u'click': <gensim.models.keyedvectors.Vocab at 0x11fbc53d0>,
#  u'machines': <gensim.models.keyedvectors.Vocab at 0x11f49ccd0>,
#  u'even': <gensim.models.keyedvectors.Vocab at 0x11fb99390>,
#  u'material': <gensim.models.keyedvectors.Vocab at 0x11fc5c7d0>,
#  u'stood': <gensim.models.keyedvectors.Vocab at 0x11fc4e1d0>,
#  u'appear': <gensim.models.keyedvectors.Vocab at 0x11f499c50>,
#  u'clock': <gensim.models.keyedvectors.Vocab at 0x11f3e4750>,
#  u'giving': <gensim.models.keyedvectors.Vocab at 0x11fc60250>,
#  u'sun': <gensim.models.keyedvectors.Vocab at 0x11fc72550>,
#  u'stool': <gensim.models.keyedvectors.Vocab at 0x11fc4e210>,
#  u'fingers': <gensim.models.keyedvectors.Vocab at 0x11f685350>,
#  u'uniform': <gensim.models.keyedvectors.Vocab at 0x11f499c90>,
#  u'business': <gensim.models.keyedvectors.Vocab at 0x11f4bdb10>,
#  u'public': <gensim.models.keyedvectors.Vocab at 0x11fc68a50>,
#  u'hungry': <gensim.models.keyedvectors.Vocab at 0x11fc55ad0>,
#  u'reconstruction': <gensim.models.keyedvectors.Vocab at 0x11f49cd10>,
#  u'sideways': <gensim.models.keyedvectors.Vocab at 0x11fba40d0>,
#  u'new': <gensim.models.keyedvectors.Vocab at 0x11fb993d0>,
#  u'falling': <gensim.models.keyedvectors.Vocab at 0x11f403650>,
#  u'carpet': <gensim.models.keyedvectors.Vocab at 0x11f49cd50>,
#  u'ever': <gensim.models.keyedvectors.Vocab at 0x11fb99410>,
#  u'bird': <gensim.models.keyedvectors.Vocab at 0x11f3cfb10>,
#  u'filled': <gensim.models.keyedvectors.Vocab at 0x11fb9f990>,
#  u'told': <gensim.models.keyedvectors.Vocab at 0x11f49cd90>,
#  u'body': <gensim.models.keyedvectors.Vocab at 0x11fc60290>,
#  u'football': <gensim.models.keyedvectors.Vocab at 0x11fc55250>,
#  u'full': <gensim.models.keyedvectors.Vocab at 0x11f3e4790>,
#  u'leg': <gensim.models.keyedvectors.Vocab at 0x11f3cfb50>,
#  u'guardian': <gensim.models.keyedvectors.Vocab at 0x11fb9f9d0>,
#  u'men': <gensim.models.keyedvectors.Vocab at 0x11edb2f10>,
#  u'water': <gensim.models.keyedvectors.Vocab at 0x11fc55510>,
#  u'believed': <gensim.models.keyedvectors.Vocab at 0x11f4038d0>,
#  u'field': <gensim.models.keyedvectors.Vocab at 0x11fba4f10>,
#  u'apartment': <gensim.models.keyedvectors.Vocab at 0x11fc72310>,
#  u'let': <gensim.models.keyedvectors.Vocab at 0x11f3cf250>,
#  u'sink': <gensim.models.keyedvectors.Vocab at 0x11fc60310>,
#  u'making': <gensim.models.keyedvectors.Vocab at 0x11fb9fb90>,
#  u'alone': <gensim.models.keyedvectors.Vocab at 0x11f403690>,
#  u'path': <gensim.models.keyedvectors.Vocab at 0x11fc68150>,
#  u'along': <gensim.models.keyedvectors.Vocab at 0x11f4036d0>,
#  u'ceiling': <gensim.models.keyedvectors.Vocab at 0x11fc68850>,
#  u'change': <gensim.models.keyedvectors.Vocab at 0x11f499cd0>,
#  u'wait': <gensim.models.keyedvectors.Vocab at 0x11fb9fa10>,
#  u'dry': <gensim.models.keyedvectors.Vocab at 0x11fb99490>,
#  u'boy': <gensim.models.keyedvectors.Vocab at 0x11fb9fa90>,
#  u'great': <gensim.models.keyedvectors.Vocab at 0x11f3cfb90>,
#  u'daughter': <gensim.models.keyedvectors.Vocab at 0x11f49cdd0>,
#  u'colored': <gensim.models.keyedvectors.Vocab at 0x11f4bdf50>,
#  u'thirty': <gensim.models.keyedvectors.Vocab at 0x11fc55550>,
#  u'study': <gensim.models.keyedvectors.Vocab at 0x11f49ce10>,
#  u'changed': <gensim.models.keyedvectors.Vocab at 0x11fc68190>,
#  u'wherever': <gensim.models.keyedvectors.Vocab at 0x11f403710>,
#  u'extreme': <gensim.models.keyedvectors.Vocab at 0x11fc60390>,
#  u'leaving': <gensim.models.keyedvectors.Vocab at 0x11fc5c3d0>,
#  u'women': <gensim.models.keyedvectors.Vocab at 0x11fc5c490>,
#  u'smoke': <gensim.models.keyedvectors.Vocab at 0x11f49ce50>,
#  u'pick': <gensim.models.keyedvectors.Vocab at 0x11f3e47d0>,
#  u'usually': <gensim.models.keyedvectors.Vocab at 0x11f499d10>,
#  u'opinion': <gensim.models.keyedvectors.Vocab at 0x11f3cfbd0>,
#  u'apart': <gensim.models.keyedvectors.Vocab at 0x11fc68e90>,
#  u'point': <gensim.models.keyedvectors.Vocab at 0x11fc4ec50>,
#  u'control': <gensim.models.keyedvectors.Vocab at 0x11fbc5590>,
#  u'bare': <gensim.models.keyedvectors.Vocab at 0x11fc72d90>,
#  u'love': <gensim.models.keyedvectors.Vocab at 0x11f403750>,
#  u'family': <gensim.models.keyedvectors.Vocab at 0x11f4bdf90>,
#  u'extra': <gensim.models.keyedvectors.Vocab at 0x11f499d50>,
#  u'suddenly': <gensim.models.keyedvectors.Vocab at 0x11fc72590>,
#  u'merely': <gensim.models.keyedvectors.Vocab at 0x11fb9fad0>,
#  u'prefer': <gensim.models.keyedvectors.Vocab at 0x11f403790>,
#  u'private': <gensim.models.keyedvectors.Vocab at 0x11f3cf610>,
#  u'brought': <gensim.models.keyedvectors.Vocab at 0x11f685150>,
#  u'put': <gensim.models.keyedvectors.Vocab at 0x11f4b6490>,
#  u'fake': <gensim.models.keyedvectors.Vocab at 0x11f4037d0>,
#  u'perhaps': <gensim.models.keyedvectors.Vocab at 0x11fc5cf10>,
#  u'janine': <gensim.models.keyedvectors.Vocab at 0x11fb994d0>,
#  u'sugar': <gensim.models.keyedvectors.Vocab at 0x11fb99c90>,
#  u'singing': <gensim.models.keyedvectors.Vocab at 0x11fbc5490>,
#  u'egg': <gensim.models.keyedvectors.Vocab at 0x11f4b6190>,
#  u'market': <gensim.models.keyedvectors.Vocab at 0x11f499d90>,
#  u'standing': <gensim.models.keyedvectors.Vocab at 0x11f3cfc10>,
#  u'use': <gensim.models.keyedvectors.Vocab at 0x11fc60110>,
#  u'bastardes': <gensim.models.keyedvectors.Vocab at 0x11f3cfc50>,
#  u'working': <gensim.models.keyedvectors.Vocab at 0x11f403810>,
#  u'army': <gensim.models.keyedvectors.Vocab at 0x11fb99510>,
#  u'remains': <gensim.models.keyedvectors.Vocab at 0x11fbc54d0>,
#  u'chairs': <gensim.models.keyedvectors.Vocab at 0x11f4b6e50>,
#  u'lying': <gensim.models.keyedvectors.Vocab at 0x11fc72cd0>,
#  u'give': <gensim.models.keyedvectors.Vocab at 0x11fb996d0>,
#  u'arms': <gensim.models.keyedvectors.Vocab at 0x11fb99550>,
#  u'next': <gensim.models.keyedvectors.Vocab at 0x11f3cfc90>,
#  u'live': <gensim.models.keyedvectors.Vocab at 0x11f499dd0>,
#  u'doubt': <gensim.models.keyedvectors.Vocab at 0x11f3cfcd0>,
#  u'music': <gensim.models.keyedvectors.Vocab at 0x11f6852d0>,
#  u'calm': <gensim.models.keyedvectors.Vocab at 0x11fb995d0>,
#  u'passport': <gensim.models.keyedvectors.Vocab at 0x11f685850>,
#  u'teeth': <gensim.models.keyedvectors.Vocab at 0x11fb9f7d0>,
#  u'taken': <gensim.models.keyedvectors.Vocab at 0x11f4b6050>,
#  u'black': <gensim.models.keyedvectors.Vocab at 0x11fba4610>,
#  u'angels': <gensim.models.keyedvectors.Vocab at 0x11f499e10>,
#  u'tell': <gensim.models.keyedvectors.Vocab at 0x11fb99610>,
#  u'level': <gensim.models.keyedvectors.Vocab at 0x11fc55390>,
#  u'phone': <gensim.models.keyedvectors.Vocab at 0x11fc68250>,
#  u'breathe': <gensim.models.keyedvectors.Vocab at 0x11fc68210>,
#  u'flat': <gensim.models.keyedvectors.Vocab at 0x11f499990>,
#  u'entrance': <gensim.models.keyedvectors.Vocab at 0x11f499e50>,
#  u'searchlight': <gensim.models.keyedvectors.Vocab at 0x11fc72690>,
#  u'door': <gensim.models.keyedvectors.Vocab at 0x11f3e4810>,
#  u'knows': <gensim.models.keyedvectors.Vocab at 0x11fc72610>,
#  u'afford': <gensim.models.keyedvectors.Vocab at 0x11f403850>,
#  u'latin': <gensim.models.keyedvectors.Vocab at 0x11fc72e10>,
#  u'ofwarren': <gensim.models.keyedvectors.Vocab at 0x11fb9f550>,
#  u'hurt': <gensim.models.keyedvectors.Vocab at 0x11f6854d0>,
#  u'glass': <gensim.models.keyedvectors.Vocab at 0x11f685d50>,
#  u'warm': <gensim.models.keyedvectors.Vocab at 0x11fb99650>,
#  u'smile': <gensim.models.keyedvectors.Vocab at 0x11f3e45d0>,
#  u'baby': <gensim.models.keyedvectors.Vocab at 0x11f3cfd10>,
#  u'hole': <gensim.models.keyedvectors.Vocab at 0x11f685d90>,
#  u'hold': <gensim.models.keyedvectors.Vocab at 0x11f685dd0>,
#  u'effort': <gensim.models.keyedvectors.Vocab at 0x11fb9fb10>,
#  u'must': <gensim.models.keyedvectors.Vocab at 0x11fc68290>,
#  u'worst': <gensim.models.keyedvectors.Vocab at 0x11fc72450>,
#  u'honey': <gensim.models.keyedvectors.Vocab at 0x11fb99710>,
#  u'keeping': <gensim.models.keyedvectors.Vocab at 0x11f3e4850>,
#  u'wool': <gensim.models.keyedvectors.Vocab at 0x11fc55b50>,
#  u'word': <gensim.models.keyedvectors.Vocab at 0x11f49ce90>,
#  u'room': <gensim.models.keyedvectors.Vocab at 0x11fb99690>,
#  u'hour': <gensim.models.keyedvectors.Vocab at 0x11fc55350>,
#  u'drawer': <gensim.models.keyedvectors.Vocab at 0x11fb9fbd0>,
#  u'car': <gensim.models.keyedvectors.Vocab at 0x11f499e90>,
#  u'pretend': <gensim.models.keyedvectors.Vocab at 0x11f403890>,
#  u'soul': <gensim.models.keyedvectors.Vocab at 0x11fb9fb50>,
#  u'worn': <gensim.models.keyedvectors.Vocab at 0x11f49cf10>,
#  u'cat': <gensim.models.keyedvectors.Vocab at 0x11f499ed0>,
#  u'strain': <gensim.models.keyedvectors.Vocab at 0x11fc4e350>,
#  u'anywhere': <gensim.models.keyedvectors.Vocab at 0x11fc5c550>,
#  u'thin': <gensim.models.keyedvectors.Vocab at 0x11f3cfd50>,
#  u'praise': <gensim.models.keyedvectors.Vocab at 0x11fc60450>,
#  u'elbow': <gensim.models.keyedvectors.Vocab at 0x11f49cf50>,
#  u'pulling': <gensim.models.keyedvectors.Vocab at 0x11fbc55d0>,
#  u'laughter': <gensim.models.keyedvectors.Vocab at 0x11fc55610>,
#  u'history': <gensim.models.keyedvectors.Vocab at 0x11f4b60d0>,
#  u'beautiful': <gensim.models.keyedvectors.Vocab at 0x11f3e4890>,
#  u'meant': <gensim.models.keyedvectors.Vocab at 0x11fbc5390>,
#  u'tap': <gensim.models.keyedvectors.Vocab at 0x11fc603d0>,
#  u'bent': <gensim.models.keyedvectors.Vocab at 0x11f3cfd90>,
#  u'figure': <gensim.models.keyedvectors.Vocab at 0x11fc55650>,
#  u'pauses': <gensim.models.keyedvectors.Vocab at 0x11f499f10>,
#  u'household': <gensim.models.keyedvectors.Vocab at 0x11f685e10>,
#  u'allowed': <gensim.models.keyedvectors.Vocab at 0x11f403910>,
#  u'table': <gensim.models.keyedvectors.Vocab at 0x11fc5cdd0>,
#  u'days': <gensim.models.keyedvectors.Vocab at 0x11fc68750>,
#  u'high': <gensim.models.keyedvectors.Vocab at 0x11f3cfdd0>,
#  u'heard': <gensim.models.keyedvectors.Vocab at 0x11f499f50>,
#  u'stroke': <gensim.models.keyedvectors.Vocab at 0x11fc5c510>,
#  u'woman': <gensim.models.keyedvectors.Vocab at 0x11fc72350>,
#  u'chin': <gensim.models.keyedvectors.Vocab at 0x11f499f90>,
#  u'road': <gensim.models.keyedvectors.Vocab at 0x11fba4d50>,
#  u'slip': <gensim.models.keyedvectors.Vocab at 0x11f3cfe10>,
#  u'sense': <gensim.models.keyedvectors.Vocab at 0x11f3e48d0>,
#  u'sharp': <gensim.models.keyedvectors.Vocab at 0x11fc4e390>,
#  u'keep': <gensim.models.keyedvectors.Vocab at 0x11fc682d0>,
#  u'dress': <gensim.models.keyedvectors.Vocab at 0x11f3e4950>,
#  u'rape': <gensim.models.keyedvectors.Vocab at 0x11fc5c590>,
#  u'risk': <gensim.models.keyedvectors.Vocab at 0x11fc60ed0>,
#  u'pink': <gensim.models.keyedvectors.Vocab at 0x11fb9fc10>,
#  u'huge': <gensim.models.keyedvectors.Vocab at 0x11f3e4990>,
#  u'siren': <gensim.models.keyedvectors.Vocab at 0x11fc4e3d0>,
#  u'end': <gensim.models.keyedvectors.Vocab at 0x11fc68350>,
#  u'winter': <gensim.models.keyedvectors.Vocab at 0x11f403950>,
#  u'turn': <gensim.models.keyedvectors.Vocab at 0x11fc55850>,
#  u'rather': <gensim.models.keyedvectors.Vocab at 0x11fc726d0>,
#  u'skirt': <gensim.models.keyedvectors.Vocab at 0x11fbc5650>,
#  u'watching': <gensim.models.keyedvectors.Vocab at 0x11fc5ca50>,
#  u'dinner': <gensim.models.keyedvectors.Vocab at 0x11fc55690>,
#  u'stayed': <gensim.models.keyedvectors.Vocab at 0x11f4b6110>,
#  u'arrangement': <gensim.models.keyedvectors.Vocab at 0x11fbc5690>,
#  u'machine': <gensim.models.keyedvectors.Vocab at 0x11f685910>,
#  u'hot': <gensim.models.keyedvectors.Vocab at 0x11f685950>,
#  u'animal': <gensim.models.keyedvectors.Vocab at 0x11f3cfe50>,
#  u'luke': <gensim.models.keyedvectors.Vocab at 0x11fc4eb10>,
#  u'answer': <gensim.models.keyedvectors.Vocab at 0x11fb99750>,
#  u'gate': <gensim.models.keyedvectors.Vocab at 0x11fc683d0>,
#  u'ordinary': <gensim.models.keyedvectors.Vocab at 0x11f49cf90>,
#  u'stand': <gensim.models.keyedvectors.Vocab at 0x11fc72110>,
#  u'ceremony': <gensim.models.keyedvectors.Vocab at 0x11fc68310>,
#  u'cupboard': <gensim.models.keyedvectors.Vocab at 0x11fc5c650>,
#  u'intended': <gensim.models.keyedvectors.Vocab at 0x11f3e49d0>,
#  u'may': <gensim.models.keyedvectors.Vocab at 0x11fb9fc50>,
#  u'watch': <gensim.models.keyedvectors.Vocab at 0x11fc689d0>,
#  u'began': <gensim.models.keyedvectors.Vocab at 0x11fc72750>,
#  u'tied': <gensim.models.keyedvectors.Vocab at 0x11f3cfe90>,
#  u'wrong': <gensim.models.keyedvectors.Vocab at 0x11f685a10>,
#  u'lay': <gensim.models.keyedvectors.Vocab at 0x11f49cfd0>,
#  u'opening': <gensim.models.keyedvectors.Vocab at 0x11fc5cc50>,
#  u'coming': <gensim.models.keyedvectors.Vocab at 0x11fc558d0>,
#  u'date': <gensim.models.keyedvectors.Vocab at 0x11f403990>,
#  u'law': <gensim.models.keyedvectors.Vocab at 0x11f499050>,
#  u'man': <gensim.models.keyedvectors.Vocab at 0x11fb9fc90>,
#  u'short': <gensim.models.keyedvectors.Vocab at 0x11fc72710>,
#  u'remember': <gensim.models.keyedvectors.Vocab at 0x11f499fd0>,
#  u'third': <gensim.models.keyedvectors.Vocab at 0x11fb99790>,
#  u'maybe': <gensim.models.keyedvectors.Vocab at 0x11fb9fcd0>,
#  u'counter': <gensim.models.keyedvectors.Vocab at 0x11f3cfed0>,
#  u'children': <gensim.models.keyedvectors.Vocab at 0x11fc68110>,
#  u'tale': <gensim.models.keyedvectors.Vocab at 0x11fb9fd10>,
#  u'tulip': <gensim.models.keyedvectors.Vocab at 0x11f685a50>,
#  u'ones': <gensim.models.keyedvectors.Vocab at 0x11fc5ca90>,
#  u'green': <gensim.models.keyedvectors.Vocab at 0x11f499090>,
#  u'silence': <gensim.models.keyedvectors.Vocab at 0x11fb9fd50>,
#  u'pay': <gensim.models.keyedvectors.Vocab at 0x11fba4b10>,
#  u'basket': <gensim.models.keyedvectors.Vocab at 0x11fb9fd90>,
#  u'tall': <gensim.models.keyedvectors.Vocab at 0x11fb9fdd0>,
#  u'pulled': <gensim.models.keyedvectors.Vocab at 0x11f4039d0>,
#  u'order': <gensim.models.keyedvectors.Vocab at 0x11f4990d0>,
#  u'wind': <gensim.models.keyedvectors.Vocab at 0x11f685ad0>,
#  u'wine': <gensim.models.keyedvectors.Vocab at 0x11f685b10>,
#  u'help': <gensim.models.keyedvectors.Vocab at 0x11f4b61d0>,
#  u'office': <gensim.models.keyedvectors.Vocab at 0x11f499110>,
#  u'food': <gensim.models.keyedvectors.Vocab at 0x11f4b6310>,
#  u'indeed': <gensim.models.keyedvectors.Vocab at 0x11fc68550>,
#  u'move': <gensim.models.keyedvectors.Vocab at 0x11f3cff10>,
#  u'soon': <gensim.models.keyedvectors.Vocab at 0x11f4b6210>,
#  u'years': <gensim.models.keyedvectors.Vocab at 0x11f403a10>,
#  u'top': <gensim.models.keyedvectors.Vocab at 0x11fc687d0>,
#  u'course': <gensim.models.keyedvectors.Vocab at 0x11f403a50>,
#  u'paper': <gensim.models.keyedvectors.Vocab at 0x11f3e4a90>,
#  u'earth': <gensim.models.keyedvectors.Vocab at 0x11fc68990>,
#  u'costume': <gensim.models.keyedvectors.Vocab at 0x11fbc56d0>,
#  u'shake': <gensim.models.keyedvectors.Vocab at 0x11fb9fe50>,
#  u'hell': <gensim.models.keyedvectors.Vocab at 0x11f4b6290>,
#  u'smiling': <gensim.models.keyedvectors.Vocab at 0x11f3e4ad0>,
#  u'nolite': <gensim.models.keyedvectors.Vocab at 0x11fb9fe90>,
#  u'forehead': <gensim.models.keyedvectors.Vocab at 0x11fc68d90>,
#  u'le': <gensim.models.keyedvectors.Vocab at 0x11fc60490>,
#  u'group': <gensim.models.keyedvectors.Vocab at 0x11fbc5c50>,
#  u'thank': <gensim.models.keyedvectors.Vocab at 0x11fb9fed0>,
#  u'fit': <gensim.models.keyedvectors.Vocab at 0x11f685b50>,
#  u'somewhere': <gensim.models.keyedvectors.Vocab at 0x11f499150>,
#  u'border': <gensim.models.keyedvectors.Vocab at 0x11fbc5990>,
#  u'writing': <gensim.models.keyedvectors.Vocab at 0x11fc68490>,
#  u'better': <gensim.models.keyedvectors.Vocab at 0x11fb997d0>,
#  u'window': <gensim.models.keyedvectors.Vocab at 0x11f4bd090>,
#  u'choose': <gensim.models.keyedvectors.Vocab at 0x11fc5c710>,
#  u'van': <gensim.models.keyedvectors.Vocab at 0x11fc4f2d0>,
#  u'orange': <gensim.models.keyedvectors.Vocab at 0x11fc5c750>,
#  u'covered': <gensim.models.keyedvectors.Vocab at 0x11fc5c790>,
#  u'hidden': <gensim.models.keyedvectors.Vocab at 0x11f685b90>,
#  u'main': <gensim.models.keyedvectors.Vocab at 0x11fb9ff10>,
#  u'might': <gensim.models.keyedvectors.Vocab at 0x11fc72810>,
#  u'happened': <gensim.models.keyedvectors.Vocab at 0x11fc556d0>,
#  u'coffee': <gensim.models.keyedvectors.Vocab at 0x11f499190>,
#  u'evening': <gensim.models.keyedvectors.Vocab at 0x11f4b62d0>,
#  u'somebody': <gensim.models.keyedvectors.Vocab at 0x11f4bd850>,
#  u'tucked': <gensim.models.keyedvectors.Vocab at 0x11fb9ff50>,
#  u'nod': <gensim.models.keyedvectors.Vocab at 0x11f4bd0d0>,
#  u'plaster': <gensim.models.keyedvectors.Vocab at 0x11fc68510>,
#  u'safe': <gensim.models.keyedvectors.Vocab at 0x11f4991d0>,
#  u'blessed': <gensim.models.keyedvectors.Vocab at 0x11fba4d90>,
#  u'break': <gensim.models.keyedvectors.Vocab at 0x11f499210>,
#  u'handmaids': <gensim.models.keyedvectors.Vocab at 0x11fb9f1d0>,
#  u'touching': <gensim.models.keyedvectors.Vocab at 0x11fb9ffd0>,
#  u'kiss': <gensim.models.keyedvectors.Vocab at 0x11f3cff50>,
#  u'half': <gensim.models.keyedvectors.Vocab at 0x11f4bd110>,
#  u'foot': <gensim.models.keyedvectors.Vocab at 0x11f4bd950>,
#  u'fear': <gensim.models.keyedvectors.Vocab at 0x11fc5c990>,
#  u'bath': <gensim.models.keyedvectors.Vocab at 0x11fc55750>,
#  u'silver': <gensim.models.keyedvectors.Vocab at 0x11f685bd0>,
#  u'bank': <gensim.models.keyedvectors.Vocab at 0x11f499250>,
#  u'bread': <gensim.models.keyedvectors.Vocab at 0x11f499290>,
#  u'easily': <gensim.models.keyedvectors.Vocab at 0x11fc4e550>,
#  u'term': <gensim.models.keyedvectors.Vocab at 0x11fc55790>,
#  u'several': <gensim.models.keyedvectors.Vocab at 0x11fc68dd0>,
#  u'cotton': <gensim.models.keyedvectors.Vocab at 0x11fbc5190>,
#  u'meat': <gensim.models.keyedvectors.Vocab at 0x11fb99850>,
#  u'pregnant': <gensim.models.keyedvectors.Vocab at 0x11fc4e590>,
#  u'always': <gensim.models.keyedvectors.Vocab at 0x11f3e4b10>,
#  u'university': <gensim.models.keyedvectors.Vocab at 0x11fbc5790>,
#  u'mothers': <gensim.models.keyedvectors.Vocab at 0x11fc4e190>,
#  u'guard': <gensim.models.keyedvectors.Vocab at 0x11fc60cd0>,
#  u'tear': <gensim.models.keyedvectors.Vocab at 0x11f403550>,
#  u'slide': <gensim.models.keyedvectors.Vocab at 0x11fbc57d0>,
#  u'weather': <gensim.models.keyedvectors.Vocab at 0x11fc4f290>,
#  u'stopped': <gensim.models.keyedvectors.Vocab at 0x11f4b6350>,
#  u'truth': <gensim.models.keyedvectors.Vocab at 0x11f3cff90>,
#  u'die': <gensim.models.keyedvectors.Vocab at 0x11fb9f8d0>,
#  u'found': <gensim.models.keyedvectors.Vocab at 0x11f3e4b50>,
#  u'beneath': <gensim.models.keyedvectors.Vocab at 0x11f3cffd0>,
#  u'tray': <gensim.models.keyedvectors.Vocab at 0x11fc5c810>,
#  u'side': <gensim.models.keyedvectors.Vocab at 0x11fb998d0>,
#  u'bone': <gensim.models.keyedvectors.Vocab at 0x11fb99910>,
#  u'mean': <gensim.models.keyedvectors.Vocab at 0x11f3e4310>,
#  u'heavy': <gensim.models.keyedvectors.Vocab at 0x11f4b6390>,
#  u'nick': <gensim.models.keyedvectors.Vocab at 0x11fc5c250>,
#  u'square': <gensim.models.keyedvectors.Vocab at 0x11f403a90>,
#  u'england': <gensim.models.keyedvectors.Vocab at 0x11fc72150>,
#  u'weight': <gensim.models.keyedvectors.Vocab at 0x11fc72890>,
#  u'house': <gensim.models.keyedvectors.Vocab at 0x11fc4e650>,
#  u'energy': <gensim.models.keyedvectors.Vocab at 0x11fc4e690>,
#  u'hard': <gensim.models.keyedvectors.Vocab at 0x11fc4e6d0>,
#  u'idea': <gensim.models.keyedvectors.Vocab at 0x11fc4e710>,
#  u'started': <gensim.models.keyedvectors.Vocab at 0x11fbc5550>,
#  u'society': <gensim.models.keyedvectors.Vocab at 0x11f49c050>,
#  u'books': <gensim.models.keyedvectors.Vocab at 0x11f49c090>,
#  u'gave': <gensim.models.keyedvectors.Vocab at 0x11fc68e50>,
#  u'expect': <gensim.models.keyedvectors.Vocab at 0x11fc728d0>,
#  u'year': <gensim.models.keyedvectors.Vocab at 0x11f4bd190>,
#  u'happen': <gensim.models.keyedvectors.Vocab at 0x11f4bd1d0>,
#  u'beyond': <gensim.models.keyedvectors.Vocab at 0x11f4b63d0>,
#  u'sexual': <gensim.models.keyedvectors.Vocab at 0x11fc604d0>,
#  u'message': <gensim.models.keyedvectors.Vocab at 0x11f685c10>,
#  u'really': <gensim.models.keyedvectors.Vocab at 0x11f3e4bd0>,
#  u'large': <gensim.models.keyedvectors.Vocab at 0x11f3e4650>,
#  u'given': <gensim.models.keyedvectors.Vocab at 0x11fc55910>,
#  u'flower': <gensim.models.keyedvectors.Vocab at 0x11fc4e750>,
#  u'opened': <gensim.models.keyedvectors.Vocab at 0x11f4bd210>,
#  u'space': <gensim.models.keyedvectors.Vocab at 0x11f4bd250>,
#  u'afraid': <gensim.models.keyedvectors.Vocab at 0x11fc5c890>,
#  u'god': <gensim.models.keyedvectors.Vocab at 0x11fc68590>,
#  u'tried': <gensim.models.keyedvectors.Vocab at 0x11f4b6150>,
#  u'since': <gensim.models.keyedvectors.Vocab at 0x11f4bddd0>,
#  u'washed': <gensim.models.keyedvectors.Vocab at 0x11fc685d0>,
#  u'bad': <gensim.models.keyedvectors.Vocab at 0x11fb99d90>,
#  u'looking': <gensim.models.keyedvectors.Vocab at 0x11f4bd290>,
#  u'hear': <gensim.models.keyedvectors.Vocab at 0x11fc55190>,
#  u'softly': <gensim.models.keyedvectors.Vocab at 0x11fb99dd0>,
#  u'mayday': <gensim.models.keyedvectors.Vocab at 0x11fc68610>,
#  u'print': <gensim.models.keyedvectors.Vocab at 0x11fc4e790>,
#  u'surprise': <gensim.models.keyedvectors.Vocab at 0x11fb99990>,
#  u'forth': <gensim.models.keyedvectors.Vocab at 0x11f4992d0>,
#  u'red': <gensim.models.keyedvectors.Vocab at 0x11f49cc90>,
#  u'oblong': <gensim.models.keyedvectors.Vocab at 0x11f49c0d0>,
#  u'shut': <gensim.models.keyedvectors.Vocab at 0x11f49c110>,
#  u'unless': <gensim.models.keyedvectors.Vocab at 0x11fc605d0>,
#  u'turning': <gensim.models.keyedvectors.Vocab at 0x11fb999d0>,
#  u'barrier': <gensim.models.keyedvectors.Vocab at 0x11f499310>,
#  u'kneel': <gensim.models.keyedvectors.Vocab at 0x11fc5cb50>,
#  u'hang': <gensim.models.keyedvectors.Vocab at 0x11f499690>,
#  u'little': <gensim.models.keyedvectors.Vocab at 0x11fba4250>,
#  u'possibility': <gensim.models.keyedvectors.Vocab at 0x11f403ad0>,
#  u'quite': <gensim.models.keyedvectors.Vocab at 0x11f403b10>,
#  u'quick': <gensim.models.keyedvectors.Vocab at 0x11fc553d0>,
#  u'reason': <gensim.models.keyedvectors.Vocab at 0x11f4b6450>,
#  u'worse': <gensim.models.keyedvectors.Vocab at 0x11fc72390>,
#  u'surely': <gensim.models.keyedvectors.Vocab at 0x11f49c150>,
#  u'murmur': <gensim.models.keyedvectors.Vocab at 0x11f3e4c50>,
#  u'imagine': <gensim.models.keyedvectors.Vocab at 0x11f3e4c90>,
#  u'ask': <gensim.models.keyedvectors.Vocab at 0x11f4bdfd0>,
#  u'sheet': <gensim.models.keyedvectors.Vocab at 0x11f4bd3d0>,
#  u'wanted': <gensim.models.keyedvectors.Vocab at 0x11fc68710>,
#  u'beginning': <gensim.models.keyedvectors.Vocab at 0x11fc4e7d0>,
#  u'guy': <gensim.models.keyedvectors.Vocab at 0x11fc72910>,
#  u'care': <gensim.models.keyedvectors.Vocab at 0x11f4bd2d0>,
#  u'thrown': <gensim.models.keyedvectors.Vocab at 0x11fc72950>,
#  u'entirely': <gensim.models.keyedvectors.Vocab at 0x11fc4f190>,
#  u'nightgown': <gensim.models.keyedvectors.Vocab at 0x11fc4f390>,
#  u'moment': <gensim.models.keyedvectors.Vocab at 0x11fc4ee10>,
#  u'times': <gensim.models.keyedvectors.Vocab at 0x11fbc5810>,
#  u'thing': <gensim.models.keyedvectors.Vocab at 0x11fba4110>,
#  u'expecting': <gensim.models.keyedvectors.Vocab at 0x11f4b64d0>,
#  u'silently': <gensim.models.keyedvectors.Vocab at 0x11fba4710>,
#  u'unknown': <gensim.models.keyedvectors.Vocab at 0x11fc5c850>,
#  u'today': <gensim.models.keyedvectors.Vocab at 0x11fc55590>,
#  u'loud': <gensim.models.keyedvectors.Vocab at 0x11fb99a10>,
#  u'think': <gensim.models.keyedvectors.Vocab at 0x11fba4150>,
#  u'first': <gensim.models.keyedvectors.Vocab at 0x11fba4190>,
#  u'blind': <gensim.models.keyedvectors.Vocab at 0x11f4bd310>,
#  u'feel': <gensim.models.keyedvectors.Vocab at 0x11fc72a10>,
#  u'wave': <gensim.models.keyedvectors.Vocab at 0x11fbc52d0>,
#  u'number': <gensim.models.keyedvectors.Vocab at 0x11f3e4cd0>,
#  u'getting': <gensim.models.keyedvectors.Vocab at 0x11fc5c4d0>,
#  u'one': <gensim.models.keyedvectors.Vocab at 0x11f403b50>,
#  u'feet': <gensim.models.keyedvectors.Vocab at 0x11fc72a50>,
#  u'hook': <gensim.models.keyedvectors.Vocab at 0x11fb99a50>,
#  u'talked': <gensim.models.keyedvectors.Vocab at 0x11fb9f950>,
#  u'done': <gensim.models.keyedvectors.Vocab at 0x11fc4e810>,
#  u'least': <gensim.models.keyedvectors.Vocab at 0x11fc4e850>,
#  u'another': <gensim.models.keyedvectors.Vocab at 0x11f499350>,
#  u'blank': <gensim.models.keyedvectors.Vocab at 0x11fc72a90>,
#  u'carry': <gensim.models.keyedvectors.Vocab at 0x11fba4210>,
#  u'impossible': <gensim.models.keyedvectors.Vocab at 0x11f4bd350>,
#  u'thick': <gensim.models.keyedvectors.Vocab at 0x11f499390>,
#  u'noticed': <gensim.models.keyedvectors.Vocab at 0x11fb990d0>,
#  u'open': <gensim.models.keyedvectors.Vocab at 0x11f403b90>,
#  u'tomorrow': <gensim.models.keyedvectors.Vocab at 0x11f685c50>,
#  u'city': <gensim.models.keyedvectors.Vocab at 0x11f403bd0>,
#  u'guess': <gensim.models.keyedvectors.Vocab at 0x11f3e4d10>,
#  u'heads': <gensim.models.keyedvectors.Vocab at 0x11f3e4d50>,
#  u'silent': <gensim.models.keyedvectors.Vocab at 0x11f4bd410>,
#  u'service': <gensim.models.keyedvectors.Vocab at 0x11f685cd0>,
#  u'downstairs': <gensim.models.keyedvectors.Vocab at 0x11fba4e10>,
#  u'twenty': <gensim.models.keyedvectors.Vocab at 0x11fc72990>,
#  u'caught': <gensim.models.keyedvectors.Vocab at 0x11f4bd450>,
#  u'girls': <gensim.models.keyedvectors.Vocab at 0x11fb99a90>,
#  u'system': <gensim.models.keyedvectors.Vocab at 0x11f49c190>,
#  u'elevator': <gensim.models.keyedvectors.Vocab at 0x11f4993d0>,
#  u'name': <gensim.models.keyedvectors.Vocab at 0x11fc557d0>,
#  u'checkpoint': <gensim.models.keyedvectors.Vocab at 0x11f3e4d90>,
#  u'needed': <gensim.models.keyedvectors.Vocab at 0x11f685d10>,
#  u'attack': <gensim.models.keyedvectors.Vocab at 0x11fbc5850>,
#  u'station': <gensim.models.keyedvectors.Vocab at 0x11f3e4910>,
#  u'passed': <gensim.models.keyedvectors.Vocab at 0x11fc72b10>,
#  u'tea': <gensim.models.keyedvectors.Vocab at 0x11fc72510>,
#  u'free': <gensim.models.keyedvectors.Vocab at 0x11fc68690>,
#  u'white': <gensim.models.keyedvectors.Vocab at 0x11fc55990>,
#  u'legs': <gensim.models.keyedvectors.Vocab at 0x11f685e90>,
#  u'friend': <gensim.models.keyedvectors.Vocab at 0x11f4bd490>,
#  u'listen': <gensim.models.keyedvectors.Vocab at 0x11f685f10>,
#  u'back': <gensim.models.keyedvectors.Vocab at 0x11fc4efd0>,
#  u'curtains': <gensim.models.keyedvectors.Vocab at 0x11fc68810>,
#  u'eyes': <gensim.models.keyedvectors.Vocab at 0x11fba4310>,
#  u'stomach': <gensim.models.keyedvectors.Vocab at 0x11f49c1d0>,
#  u'lot': <gensim.models.keyedvectors.Vocab at 0x11f4bdc90>,
#  u'behind': <gensim.models.keyedvectors.Vocab at 0x11fba45d0>,
#  u'exactly': <gensim.models.keyedvectors.Vocab at 0x11fbc5890>,
#  u'sick': <gensim.models.keyedvectors.Vocab at 0x11fc5cfd0>,
#  u'took': <gensim.models.keyedvectors.Vocab at 0x11fc68890>,
#  u'part': <gensim.models.keyedvectors.Vocab at 0x11fc4e8d0>,
#  u'flowers': <gensim.models.keyedvectors.Vocab at 0x11f4bd4d0>,
#  u'stairs': <gensim.models.keyedvectors.Vocab at 0x11fc72d10>,
#  u'neck': <gensim.models.keyedvectors.Vocab at 0x11fbc58d0>,
#  u'steel': <gensim.models.keyedvectors.Vocab at 0x11f49c210>,
#  u'wide': <gensim.models.keyedvectors.Vocab at 0x11fc559d0>,
#  u'television': <gensim.models.keyedvectors.Vocab at 0x11f4bd510>,
#  u'hundred': <gensim.models.keyedvectors.Vocab at 0x11f4b6510>,
#  u'decided': <gensim.models.keyedvectors.Vocab at 0x11fb99e10>,
#  u'showed': <gensim.models.keyedvectors.Vocab at 0x11f685e50>,
#  u'double': <gensim.models.keyedvectors.Vocab at 0x11fc72bd0>,
#  u'bother': <gensim.models.keyedvectors.Vocab at 0x11f49c250>,
#  u'older': <gensim.models.keyedvectors.Vocab at 0x11f4b6d10>,
#  u'tree': <gensim.models.keyedvectors.Vocab at 0x11f685ed0>,
#  u'likely': <gensim.models.keyedvectors.Vocab at 0x11fb99350>,
#  u'bed': <gensim.models.keyedvectors.Vocab at 0x11fbc5910>,
#  u'matter': <gensim.models.keyedvectors.Vocab at 0x11fb99ad0>,
#  u'future': <gensim.models.keyedvectors.Vocab at 0x11f403c10>,
#  u'store': <gensim.models.keyedvectors.Vocab at 0x11f4b6590>,
#  u'historical': <gensim.models.keyedvectors.Vocab at 0x11fc4ec10>,
#  u'light': <gensim.models.keyedvectors.Vocab at 0x11fc5c690>,
#  u'anyone': <gensim.models.keyedvectors.Vocab at 0x11fba4290>,
#  u'feeling': <gensim.models.keyedvectors.Vocab at 0x11f685f50>,
#  u'minor': <gensim.models.keyedvectors.Vocab at 0x11fc725d0>,
#  u'angel': <gensim.models.keyedvectors.Vocab at 0x11f4bd550>,
#  u'film': <gensim.models.keyedvectors.Vocab at 0x11fba4e90>,
#  u'turned': <gensim.models.keyedvectors.Vocab at 0x11f403c50>,
#  u'gently': <gensim.models.keyedvectors.Vocab at 0x11f49c290>,
#  u'sad': <gensim.models.keyedvectors.Vocab at 0x11f403c90>,
#  u'tonight': <gensim.models.keyedvectors.Vocab at 0x11f49c2d0>,
#  u'juice': <gensim.models.keyedvectors.Vocab at 0x11f4b65d0>,
#  u'say': <gensim.models.keyedvectors.Vocab at 0x11f403cd0>,
#  u'blond': <gensim.models.keyedvectors.Vocab at 0x11f3e4dd0>,
#  u'need': <gensim.models.keyedvectors.Vocab at 0x11fbc5950>,
#  u'seen': <gensim.models.keyedvectors.Vocab at 0x11fb99b90>,
#  u'breakfast': <gensim.models.keyedvectors.Vocab at 0x11f4bd590>,
#  u'saw': <gensim.models.keyedvectors.Vocab at 0x11f403d10>,
#  u'sat': <gensim.models.keyedvectors.Vocab at 0x11f403d50>,
#  u'lie': <gensim.models.keyedvectors.Vocab at 0x11f4b6610>,
#  u'breathing': <gensim.models.keyedvectors.Vocab at 0x11fc5c310>,
#  u'speaking': <gensim.models.keyedvectors.Vocab at 0x11fba42d0>,
#  u'place': <gensim.models.keyedvectors.Vocab at 0x11fc55890>,
#  u'able': <gensim.models.keyedvectors.Vocab at 0x11fbc59d0>,
#  u'aside': <gensim.models.keyedvectors.Vocab at 0x11f403d90>,
#  u'arm': <gensim.models.keyedvectors.Vocab at 0x11fc72dd0>,
#  u'lit': <gensim.models.keyedvectors.Vocab at 0x11f4b6650>,
#  u'also': <gensim.models.keyedvectors.Vocab at 0x11f3e4e10>,
#  u'edge': <gensim.models.keyedvectors.Vocab at 0x11fc5c050>,
#  u'lip': <gensim.models.keyedvectors.Vocab at 0x11f4b6690>,
#  u'take': <gensim.models.keyedvectors.Vocab at 0x11f403dd0>,
#  u'doors': <gensim.models.keyedvectors.Vocab at 0x11f685f90>,
#  u'wonder': <gensim.models.keyedvectors.Vocab at 0x11fba4790>,
#  u'lily': <gensim.models.keyedvectors.Vocab at 0x11f49c310>,
#  u'soap': <gensim.models.keyedvectors.Vocab at 0x11f49c350>,
#  u'blue': <gensim.models.keyedvectors.Vocab at 0x11fc68090>,
#  u'play': <gensim.models.keyedvectors.Vocab at 0x11f3e4e50>,
#  u'towards': <gensim.models.keyedvectors.Vocab at 0x11f4b66d0>,
#  u'pain': <gensim.models.keyedvectors.Vocab at 0x11fba4350>,
#  u'serena': <gensim.models.keyedvectors.Vocab at 0x11fc4e990>,
#  u'normal': <gensim.models.keyedvectors.Vocab at 0x11fba4390>,
#  u'track': <gensim.models.keyedvectors.Vocab at 0x11fba43d0>,
#  u'eggs': <gensim.models.keyedvectors.Vocab at 0x11fc4e9d0>,
#  u'knew': <gensim.models.keyedvectors.Vocab at 0x11f403e10>,
#  u'reach': <gensim.models.keyedvectors.Vocab at 0x11fc72c10>,
#  u'paid': <gensim.models.keyedvectors.Vocab at 0x11fba4410>,
#  u'cigarette': <gensim.models.keyedvectors.Vocab at 0x11fc72c50>,
#  u'said': <gensim.models.keyedvectors.Vocab at 0x11fb99e90>,
#  u'mouth': <gensim.models.keyedvectors.Vocab at 0x11f685fd0>,
#  u'ofglen': <gensim.models.keyedvectors.Vocab at 0x11f3e4e90>,
#  u'pleasure': <gensim.models.keyedvectors.Vocab at 0x11fc4e450>,
#  u'pair': <gensim.models.keyedvectors.Vocab at 0x11fba4450>,
#  u'hide': <gensim.models.keyedvectors.Vocab at 0x11fc680d0>,
#  u'darkness': <gensim.models.keyedvectors.Vocab at 0x11f4bde90>,
#  u'lawn': <gensim.models.keyedvectors.Vocab at 0x11f403e50>,
#  u'stupid': <gensim.models.keyedvectors.Vocab at 0x11fba46d0>,
#  u'especially': <gensim.models.keyedvectors.Vocab at 0x11fba4490>,
#  u'cloth': <gensim.models.keyedvectors.Vocab at 0x11fc5c150>,
#  u'considered': <gensim.models.keyedvectors.Vocab at 0x11fc55a90>,
#  u'dream': <gensim.models.keyedvectors.Vocab at 0x11f4bd610>,
#  u'professor': <gensim.models.keyedvectors.Vocab at 0x11edb26d0>,
#  u'sometimes': <gensim.models.keyedvectors.Vocab at 0x11f3e4ed0>,
#  u'cover': <gensim.models.keyedvectors.Vocab at 0x11f3e4f10>,
#  u'dog': <gensim.models.keyedvectors.Vocab at 0x11fb99c10>,
#  u'face': <gensim.models.keyedvectors.Vocab at 0x11f49c390>,
#  u'looked': <gensim.models.keyedvectors.Vocab at 0x11fc5c950>,
#  u'aunt': <gensim.models.keyedvectors.Vocab at 0x11f499410>,
#  u'talk': <gensim.models.keyedvectors.Vocab at 0x11fb9fe10>,
#  u'clean': <gensim.models.keyedvectors.Vocab at 0x11f4b6750>,
#  u'occasion': <gensim.models.keyedvectors.Vocab at 0x11fc60610>,
#  u'usual': <gensim.models.keyedvectors.Vocab at 0x11fc60a10>,
#  u'scream': <gensim.models.keyedvectors.Vocab at 0x11edb2ad0>,
#  u'fact': <gensim.models.keyedvectors.Vocab at 0x11f49c3d0>,
#  u'saying': <gensim.models.keyedvectors.Vocab at 0x11edb2750>,
#  u'walking': <gensim.models.keyedvectors.Vocab at 0x11f403e90>,
#  u'marthas': <gensim.models.keyedvectors.Vocab at 0x11f49c410>,
#  u'shot': <gensim.models.keyedvectors.Vocab at 0x11fba44d0>,
#  u'gold': <gensim.models.keyedvectors.Vocab at 0x11f3e4f50>,
#  u'show': <gensim.models.keyedvectors.Vocab at 0x11fba4510>,
#  u'anyway': <gensim.models.keyedvectors.Vocab at 0x11fbc5a50>,
#  u'hotel': <gensim.models.keyedvectors.Vocab at 0x11fc72b50>,
#  u'discovered': <gensim.models.keyedvectors.Vocab at 0x11f4bd690>,
#  u'bring': <gensim.models.keyedvectors.Vocab at 0x11f49c450>,
#  u'bright': <gensim.models.keyedvectors.Vocab at 0x11f403ed0>,
#  u'shoe': <gensim.models.keyedvectors.Vocab at 0x11fba4550>,
#  u'bedroom': <gensim.models.keyedvectors.Vocab at 0x11f499c10>,
#  u'carefully': <gensim.models.keyedvectors.Vocab at 0x11fc4ea10>,
#  u'corner': <gensim.models.keyedvectors.Vocab at 0x11fba4590>,
#  u'chicken': <gensim.models.keyedvectors.Vocab at 0x11fc55490>,
#  u'fine': <gensim.models.keyedvectors.Vocab at 0x11fc4ea50>,
#  u'find': <gensim.models.keyedvectors.Vocab at 0x11fc4ea90>,
#  u'handmaid': <gensim.models.keyedvectors.Vocab at 0x11fc60650>,
#  u'ground': <gensim.models.keyedvectors.Vocab at 0x11f685410>,
#  u'painted': <gensim.models.keyedvectors.Vocab at 0x11fc5ce10>,
#  u'envy': <gensim.models.keyedvectors.Vocab at 0x11fbc5ad0>,
#  u'pause': <gensim.models.keyedvectors.Vocab at 0x11f49c490>,
#  u'stair': <gensim.models.keyedvectors.Vocab at 0x11f4bd6d0>,
#  u'daily': <gensim.models.keyedvectors.Vocab at 0x11fb9f790>,
#  u'folded': <gensim.models.keyedvectors.Vocab at 0x11fb99c50>,
#  u'cloak': <gensim.models.keyedvectors.Vocab at 0x11f403f10>,
#  u'eat': <gensim.models.keyedvectors.Vocab at 0x11fb99150>,
#  u'going': <gensim.models.keyedvectors.Vocab at 0x11f403f50>,
#  u'tape': <gensim.models.keyedvectors.Vocab at 0x11f49c4d0>,
#  u'pretty': <gensim.models.keyedvectors.Vocab at 0x11f4b6790>,
#  u'circle': <gensim.models.keyedvectors.Vocab at 0x11f4b67d0>,
#  u'gileadean': <gensim.models.keyedvectors.Vocab at 0x11f403f90>,
#  u'hope': <gensim.models.keyedvectors.Vocab at 0x11f49c510>,
#  u'exchanged': <gensim.models.keyedvectors.Vocab at 0x11f49c550>,
#  u'plate': <gensim.models.keyedvectors.Vocab at 0x11edb2b50>,
#  u'hit': <gensim.models.keyedvectors.Vocab at 0x11fbc5610>,
#  u'therefore': <gensim.models.keyedvectors.Vocab at 0x11fc4ead0>,
#  u'get': <gensim.models.keyedvectors.Vocab at 0x11fba4650>,
#  u'familiar': <gensim.models.keyedvectors.Vocab at 0x11f49c590>,
#  u'stop': <gensim.models.keyedvectors.Vocab at 0x11fb99d10>,
#  u'lucky': <gensim.models.keyedvectors.Vocab at 0x11f49c5d0>,
#  u'trees': <gensim.models.keyedvectors.Vocab at 0x11f4b6810>,
#  u'pocket': <gensim.models.keyedvectors.Vocab at 0x11edb2ed0>,
#  u'whistle': <gensim.models.keyedvectors.Vocab at 0x11fc72d50>,
#  u'cannot': <gensim.models.keyedvectors.Vocab at 0x11f4bd710>,
#  u'breast': <gensim.models.keyedvectors.Vocab at 0x11fc4eb50>,
#  u'cushion': <gensim.models.keyedvectors.Vocab at 0x11edb2a50>,
#  u'probably': <gensim.models.keyedvectors.Vocab at 0x11f4b6910>,
#  u'trade': <gensim.models.keyedvectors.Vocab at 0x11f3e4a50>,
#  u'learned': <gensim.models.keyedvectors.Vocab at 0x11f4bded0>,
#  u'sweat': <gensim.models.keyedvectors.Vocab at 0x11fc4f250>,
#  u'quiet': <gensim.models.keyedvectors.Vocab at 0x11fc55c50>,
#  u'gray': <gensim.models.keyedvectors.Vocab at 0x11fbc5b10>,
#  u'sleeve': <gensim.models.keyedvectors.Vocab at 0x11f3e4f90>,
#  u'held': <gensim.models.keyedvectors.Vocab at 0x11f4b6250>,
#  u'leather': <gensim.models.keyedvectors.Vocab at 0x11f4bd750>,
#  u'cry': <gensim.models.keyedvectors.Vocab at 0x11f3e4fd0>,
#  u'perfume': <gensim.models.keyedvectors.Vocab at 0x11f4b6890>,
#  u'bag': <gensim.models.keyedvectors.Vocab at 0x11fb99d50>,
#  u'offred': <gensim.models.keyedvectors.Vocab at 0x11f499450>,
#  u'stuff': <gensim.models.keyedvectors.Vocab at 0x11f49c610>,
#  u'common': <gensim.models.keyedvectors.Vocab at 0x11fc4eb90>,
#  u'dangerous': <gensim.models.keyedvectors.Vocab at 0x11fba4950>,
#  u'distant': <gensim.models.keyedvectors.Vocab at 0x11fbc5dd0>,
#  u'river': <gensim.models.keyedvectors.Vocab at 0x11f3cf090>,
#  u'husband': <gensim.models.keyedvectors.Vocab at 0x11f4bd790>,
#  u'view': <gensim.models.keyedvectors.Vocab at 0x11fc5cb90>,
#  u'knowing': <gensim.models.keyedvectors.Vocab at 0x11fc5cbd0>,
#  u'set': <gensim.models.keyedvectors.Vocab at 0x11f3cf0d0>,
#  u'habit': <gensim.models.keyedvectors.Vocab at 0x11fc68a90>,
#  u'sex': <gensim.models.keyedvectors.Vocab at 0x11f3cf110>,
#  u'see': <gensim.models.keyedvectors.Vocab at 0x11f3cf150>,
#  u'accused': <gensim.models.keyedvectors.Vocab at 0x11fb99090>,
#  u'college': <gensim.models.keyedvectors.Vocab at 0x11fc55b90>,
#  u'driveway': <gensim.models.keyedvectors.Vocab at 0x11fc55a10>,
#  u'existence': <gensim.models.keyedvectors.Vocab at 0x11fc4e490>,
#  u'sleeping': <gensim.models.keyedvectors.Vocab at 0x11fba49d0>,
#  u'close': <gensim.models.keyedvectors.Vocab at 0x11f4b68d0>,
#  u'cold': <gensim.models.keyedvectors.Vocab at 0x11f4bd050>,
#  u'best': <gensim.models.keyedvectors.Vocab at 0x11edb2990>,
#  u'subject': <gensim.models.keyedvectors.Vocab at 0x11fb99e50>,
#  u'destroyed': <gensim.models.keyedvectors.Vocab at 0x11fc684d0>,
#  u'knees': <gensim.models.keyedvectors.Vocab at 0x11fc5c910>,
#  u'wire': <gensim.models.keyedvectors.Vocab at 0x11f49c650>,
#  u'onto': <gensim.models.keyedvectors.Vocab at 0x11fc68790>,
#  u'temptation': <gensim.models.keyedvectors.Vocab at 0x11fc68ad0>,
#  u'mine': <gensim.models.keyedvectors.Vocab at 0x11fb99b50>,
#  u'movie': <gensim.models.keyedvectors.Vocab at 0x11f3cf190>,
#  u'away': <gensim.models.keyedvectors.Vocab at 0x11f499490>,
#  u'exchange': <gensim.models.keyedvectors.Vocab at 0x11fc602d0>,
#  u'please': <gensim.models.keyedvectors.Vocab at 0x11fc4ebd0>,
#  u'kind': <gensim.models.keyedvectors.Vocab at 0x11fc72b90>,
#  u'kneeling': <gensim.models.keyedvectors.Vocab at 0x11fc55f90>,
#  u'case': <gensim.models.keyedvectors.Vocab at 0x11fc55e10>,
#  u'state': <gensim.models.keyedvectors.Vocab at 0x11fbc5b90>,
#  u'fish': <gensim.models.keyedvectors.Vocab at 0x11fc72190>,
#  u'finger': <gensim.models.keyedvectors.Vocab at 0x11fc68b10>,
#  u'closed': <gensim.models.keyedvectors.Vocab at 0x11fc5cc10>,
#  u'routine': <gensim.models.keyedvectors.Vocab at 0x11fc606d0>,
#  u'drawn': <gensim.models.keyedvectors.Vocab at 0x11f4994d0>,
#  u'neither': <gensim.models.keyedvectors.Vocab at 0x11fbc5bd0>,
#  u'reading': <gensim.models.keyedvectors.Vocab at 0x11fba47d0>,
#  u'across': <gensim.models.keyedvectors.Vocab at 0x11fba4810>,
#  u'rita': <gensim.models.keyedvectors.Vocab at 0x11f3cf1d0>,
#  u'supposed': <gensim.models.keyedvectors.Vocab at 0x11fc4e950>,
#  u'available': <gensim.models.keyedvectors.Vocab at 0x11f3cf210>,
#  u'notice': <gensim.models.keyedvectors.Vocab at 0x11f4bd7d0>,
#  u'loose': <gensim.models.keyedvectors.Vocab at 0x11f4bdf10>,
#  u'nature': <gensim.models.keyedvectors.Vocab at 0x11edb2510>,
#  u'rolled': <gensim.models.keyedvectors.Vocab at 0x11edb2dd0>,
#  u'joy': <gensim.models.keyedvectors.Vocab at 0x11fc5cc90>,
#  u'screen': <gensim.models.keyedvectors.Vocab at 0x11f403fd0>,
#  u'attention': <gensim.models.keyedvectors.Vocab at 0x11fc72e50>,
#  u'metal': <gensim.models.keyedvectors.Vocab at 0x11fc68950>,
#  u'lotion': <gensim.models.keyedvectors.Vocab at 0x11fb99ed0>,
#  u'job': <gensim.models.keyedvectors.Vocab at 0x11fc5ccd0>,
#  u'cut': <gensim.models.keyedvectors.Vocab at 0x11fc4ee90>,
#  u'wear': <gensim.models.keyedvectors.Vocab at 0x11fc68b90>,
#  u'key': <gensim.models.keyedvectors.Vocab at 0x11fbc5c10>,
#  u'news': <gensim.models.keyedvectors.Vocab at 0x11fc68bd0>,
#  u'outfit': <gensim.models.keyedvectors.Vocab at 0x11fc72e90>,
#  u'come': <gensim.models.keyedvectors.Vocab at 0x11fc55c10>,
#  u'kitchen': <gensim.models.keyedvectors.Vocab at 0x11f499510>,
#  u'century': <gensim.models.keyedvectors.Vocab at 0x11fc4ed10>,
#  u'weeks': <gensim.models.keyedvectors.Vocab at 0x11fb99810>,
#  u'instant': <gensim.models.keyedvectors.Vocab at 0x11fc60710>,
#  u'many': <gensim.models.keyedvectors.Vocab at 0x11f3e4050>,
#  u'taking': <gensim.models.keyedvectors.Vocab at 0x11fc60790>,
#  u'cup': <gensim.models.keyedvectors.Vocab at 0x11fc4eed0>,
#  u'according': <gensim.models.keyedvectors.Vocab at 0x11fba4850>,
#  u'called': <gensim.models.keyedvectors.Vocab at 0x11fc5c190>,
#  u'doorway': <gensim.models.keyedvectors.Vocab at 0x11f49c690>,
#  u'reply': <gensim.models.keyedvectors.Vocab at 0x11fc554d0>,
#  u'passing': <gensim.models.keyedvectors.Vocab at 0x11f4bd910>,
#  u'whole': <gensim.models.keyedvectors.Vocab at 0x11f3cf290>,
#  u'asked': <gensim.models.keyedvectors.Vocab at 0x11edb2c90>,
#  u'otherwise': <gensim.models.keyedvectors.Vocab at 0x11fc607d0>,
#  u'duty': <gensim.models.keyedvectors.Vocab at 0x11fc55c90>,
#  u'among': <gensim.models.keyedvectors.Vocab at 0x11fba4890>,
#  u'liked': <gensim.models.keyedvectors.Vocab at 0x11f4b6950>,
#  u'words': <gensim.models.keyedvectors.Vocab at 0x11fc5cad0>,
#  u'afterwards': <gensim.models.keyedvectors.Vocab at 0x11fc55cd0>,
#  u'drunk': <gensim.models.keyedvectors.Vocab at 0x11f3cf2d0>,
#  u'color': <gensim.models.keyedvectors.Vocab at 0x11fc55d10>,
#  u'sky': <gensim.models.keyedvectors.Vocab at 0x11fc5cf90>,
#  u'others': <gensim.models.keyedvectors.Vocab at 0x11fc60350>,
#  u'period': <gensim.models.keyedvectors.Vocab at 0x11fc55d50>,
#  u'whatever': <gensim.models.keyedvectors.Vocab at 0x11f4b6990>,
#  u'walk': <gensim.models.keyedvectors.Vocab at 0x11fc5cd90>,
#  u'whisper': <gensim.models.keyedvectors.Vocab at 0x11fbc5cd0>,
#  u'laugh': <gensim.models.keyedvectors.Vocab at 0x11fc60810>,
#  u'church': <gensim.models.keyedvectors.Vocab at 0x11f3cf310>,
#  u'whispering': <gensim.models.keyedvectors.Vocab at 0x11f49c6d0>,
#  u'mattress': <gensim.models.keyedvectors.Vocab at 0x11fc72790>,
#  u'trust': <gensim.models.keyedvectors.Vocab at 0x11fc68c50>,
#  u'speak': <gensim.models.keyedvectors.Vocab at 0x11f499550>,
#  u'late': <gensim.models.keyedvectors.Vocab at 0x11fc4e4d0>,
#  u'bathroom': <gensim.models.keyedvectors.Vocab at 0x11fc68c90>,
#  u'raise': <gensim.models.keyedvectors.Vocab at 0x11fc4f1d0>,
#  u'asks': <gensim.models.keyedvectors.Vocab at 0x11fb99f10>,
#  u'ear': <gensim.models.keyedvectors.Vocab at 0x11fc5ca10>,
#  u'damp': <gensim.models.keyedvectors.Vocab at 0x11f4b69d0>,
#  u'three': <gensim.models.keyedvectors.Vocab at 0x11fb99f50>,
#  u'tiny': <gensim.models.keyedvectors.Vocab at 0x11fb99f90>,
#  u'mark': <gensim.models.keyedvectors.Vocab at 0x11fba48d0>,
#  u'breath': <gensim.models.keyedvectors.Vocab at 0x11f3e4090>,
#  u'secret': <gensim.models.keyedvectors.Vocab at 0x11fc4ec90>,
#  u'much': <gensim.models.keyedvectors.Vocab at 0x11edb2690>,
#  u'slowly': <gensim.models.keyedvectors.Vocab at 0x11fbc5c90>,
#  u'interest': <gensim.models.keyedvectors.Vocab at 0x11fb99fd0>,
#  u'certain': <gensim.models.keyedvectors.Vocab at 0x11f3e4490>,
#  u'expected': <gensim.models.keyedvectors.Vocab at 0x11fc68d10>,
#  u'curtain': <gensim.models.keyedvectors.Vocab at 0x11fc60850>,
#  u'pretending': <gensim.models.keyedvectors.Vocab at 0x11f4b6850>,
#  u'waste': <gensim.models.keyedvectors.Vocab at 0x11f49c710>,
#  u'hardly': <gensim.models.keyedvectors.Vocab at 0x11fc55d90>,
#  u'empty': <gensim.models.keyedvectors.Vocab at 0x11f4b6a10>,
#  u'box': <gensim.models.keyedvectors.Vocab at 0x11fb9fa50>,
#  u'life': <gensim.models.keyedvectors.Vocab at 0x11edb2f50>,
#  u'lived': <gensim.models.keyedvectors.Vocab at 0x11f4b6a90>,
#  u'partly': <gensim.models.keyedvectors.Vocab at 0x11f4b6ad0>,
#  u'ghost': <gensim.models.keyedvectors.Vocab at 0x11fb99110>,
#  u'fire': <gensim.models.keyedvectors.Vocab at 0x11f3cf350>,
#  u'mind': <gensim.models.keyedvectors.Vocab at 0x11fb99b10>,
#  u'thousand': <gensim.models.keyedvectors.Vocab at 0x11fba4f50>,
#  u'else': <gensim.models.keyedvectors.Vocab at 0x11fb99210>,
#  u'sort': <gensim.models.keyedvectors.Vocab at 0x11fc5c450>,
#  u'finished': <gensim.models.keyedvectors.Vocab at 0x11fc60890>,
#  u'lift': <gensim.models.keyedvectors.Vocab at 0x11edb2a90>,
#  u'awake': <gensim.models.keyedvectors.Vocab at 0x11f3cf390>,
#  u'child': <gensim.models.keyedvectors.Vocab at 0x11edb2cd0>,
#  u'catch': <gensim.models.keyedvectors.Vocab at 0x11fc68d50>,
#  u'last': <gensim.models.keyedvectors.Vocab at 0x11fc5ce50>,
#  u'worked': <gensim.models.keyedvectors.Vocab at 0x11edb2c50>,
#  u'pig': <gensim.models.keyedvectors.Vocab at 0x11fc60dd0>,
#  u'despite': <gensim.models.keyedvectors.Vocab at 0x11fc68a10>,
#  u'former': <gensim.models.keyedvectors.Vocab at 0x11f3e40d0>,
#  u'present': <gensim.models.keyedvectors.Vocab at 0x11fc5ce90>,
#  u'sound': <gensim.models.keyedvectors.Vocab at 0x11fba4990>,
#  u'wood': <gensim.models.keyedvectors.Vocab at 0x11fc55b10>,
#  u'look': <gensim.models.keyedvectors.Vocab at 0x11f4b6b50>,
#  u'talking': <gensim.models.keyedvectors.Vocab at 0x11fc688d0>,
#  u'straight': <gensim.models.keyedvectors.Vocab at 0x11f3cf3d0>,
#  u'air': <gensim.models.keyedvectors.Vocab at 0x11f4995d0>,
#  u'rope': <gensim.models.keyedvectors.Vocab at 0x11f4b6b90>,
#  u'near': <gensim.models.keyedvectors.Vocab at 0x11fb9f050>,
#  u'suppose': <gensim.models.keyedvectors.Vocab at 0x11fb9f090>,
#  u'ought': <gensim.models.keyedvectors.Vocab at 0x11f4b6bd0>,
#  u'leaning': <gensim.models.keyedvectors.Vocab at 0x11f3cf410>,
#  u'voice': <gensim.models.keyedvectors.Vocab at 0x11f499610>,
#  u'mistake': <gensim.models.keyedvectors.Vocab at 0x11f499650>,
#  u'remembering': <gensim.models.keyedvectors.Vocab at 0x11edb2c10>,
#  u'cane': <gensim.models.keyedvectors.Vocab at 0x11fb9f0d0>,
#  u'played': <gensim.models.keyedvectors.Vocab at 0x11edb2450>,
#  u'blood': <gensim.models.keyedvectors.Vocab at 0x11fc4e410>,
#  u'thus': <gensim.models.keyedvectors.Vocab at 0x11fc5ced0>,
#  u'commander': <gensim.models.keyedvectors.Vocab at 0x11f4bd810>,
#  u'helped': <gensim.models.keyedvectors.Vocab at 0x11fc608d0>,
#  u'middle': <gensim.models.keyedvectors.Vocab at 0x11fba4a10>,
#  u'good': <gensim.models.keyedvectors.Vocab at 0x11fc4e510>,
#  u'ready': <gensim.models.keyedvectors.Vocab at 0x11f4b6c10>,
#  u'partner': <gensim.models.keyedvectors.Vocab at 0x11fc60910>,
#  u'sits': <gensim.models.keyedvectors.Vocab at 0x11f49c750>,
#  u'seem': <gensim.models.keyedvectors.Vocab at 0x11fb99bd0>,
#  u'worry': <gensim.models.keyedvectors.Vocab at 0x11f4bd890>,
#  u'grown': <gensim.models.keyedvectors.Vocab at 0x11fb9f110>,
#  u'funny': <gensim.models.keyedvectors.Vocab at 0x11f3cf450>,
#  u'different': <gensim.models.keyedvectors.Vocab at 0x11fba4a50>,
#  u'pas': <gensim.models.keyedvectors.Vocab at 0x11fba4a90>,
#  u'shirt': <gensim.models.keyedvectors.Vocab at 0x11fc72f10>,
#  u'anymore': <gensim.models.keyedvectors.Vocab at 0x11f4b6c50>,
#  u'doctor': <gensim.models.keyedvectors.Vocab at 0x11fba4ad0>,
#  u'wearing': <gensim.models.keyedvectors.Vocab at 0x11fb99cd0>,
#  u'things': <gensim.models.keyedvectors.Vocab at 0x11edb29d0>,
#  u'make': <gensim.models.keyedvectors.Vocab at 0x11fb9f150>,
#  u'morning': <gensim.models.keyedvectors.Vocab at 0x11fba4690>,
#  u'bowl': <gensim.models.keyedvectors.Vocab at 0x11f3e4a10>,
#  u'cross': <gensim.models.keyedvectors.Vocab at 0x11fc5cf50>,
#  u'beside': <gensim.models.keyedvectors.Vocab at 0x11fc68450>,
#  u'rules': <gensim.models.keyedvectors.Vocab at 0x11f4bda90>,
#  u'strange': <gensim.models.keyedvectors.Vocab at 0x11fc727d0>,
#  u'speech': <gensim.models.keyedvectors.Vocab at 0x11fba4b50>,
#  u'belly': <gensim.models.keyedvectors.Vocab at 0x11fb9f190>,
#  u'corridor': <gensim.models.keyedvectors.Vocab at 0x11fc4ed50>,
#  u'underground': <gensim.models.keyedvectors.Vocab at 0x11fbc5d50>,
#  u'colonies': <gensim.models.keyedvectors.Vocab at 0x11fb9f210>,
#  u'regime': <gensim.models.keyedvectors.Vocab at 0x11f499a90>,
#  u'showing': <gensim.models.keyedvectors.Vocab at 0x11f4b6d50>,
#  u'day': <gensim.models.keyedvectors.Vocab at 0x11fc4ed90>,
#  u'week': <gensim.models.keyedvectors.Vocab at 0x11f3e4b90>,
#  u'hallway': <gensim.models.keyedvectors.Vocab at 0x11f4b6c90>,
#  u'outside': <gensim.models.keyedvectors.Vocab at 0x11fc55bd0>,
#  u'used': <gensim.models.keyedvectors.Vocab at 0x11f4b6cd0>,
#  u'knitting': <gensim.models.keyedvectors.Vocab at 0x11f3cf4d0>,
#  u'breasts': <gensim.models.keyedvectors.Vocab at 0x11fc5c2d0>,
#  u'drink': <gensim.models.keyedvectors.Vocab at 0x11f4b6410>,
#  u'upon': <gensim.models.keyedvectors.Vocab at 0x11f49c790>,
#  u'yesterday': <gensim.models.keyedvectors.Vocab at 0x11fc4edd0>,
#  u'rain': <gensim.models.keyedvectors.Vocab at 0x11fc686d0>,
#  u'hand': <gensim.models.keyedvectors.Vocab at 0x11f4996d0>,
#  u'running': <gensim.models.keyedvectors.Vocab at 0x11fba4b90>,
#  u'fruit': <gensim.models.keyedvectors.Vocab at 0x11f4bd8d0>,
#  u'moving': <gensim.models.keyedvectors.Vocab at 0x11fc72f50>,
#  u'purpose': <gensim.models.keyedvectors.Vocab at 0x11f685c90>,
#  u'never': <gensim.models.keyedvectors.Vocab at 0x11fb99450>,
#  u'canopy': <gensim.models.keyedvectors.Vocab at 0x11fc5cd10>,
#  u'butter': <gensim.models.keyedvectors.Vocab at 0x11fb9f250>,
#  u'early': <gensim.models.keyedvectors.Vocab at 0x11f4bdad0>,
#  u'lower': <gensim.models.keyedvectors.Vocab at 0x11fc72f90>,
#  u'kept': <gensim.models.keyedvectors.Vocab at 0x11f499710>,
#  u'aunts': <gensim.models.keyedvectors.Vocab at 0x11fb9f710>,
#  u'whispers': <gensim.models.keyedvectors.Vocab at 0x11f49c890>,
#  u'nevertheless': <gensim.models.keyedvectors.Vocab at 0x11f4b6550>,
#  u'try': <gensim.models.keyedvectors.Vocab at 0x11f3e4c10>,
#  u'cheek': <gensim.models.keyedvectors.Vocab at 0x11fc72fd0>,
#  u'well': <gensim.models.keyedvectors.Vocab at 0x11fbc5d90>,
#  u'center': <gensim.models.keyedvectors.Vocab at 0x11fc60950>,
#  u'thought': <gensim.models.keyedvectors.Vocab at 0x11fc60990>,
#  u'person': <gensim.models.keyedvectors.Vocab at 0x11f3cf510>,
#  u'without': <gensim.models.keyedvectors.Vocab at 0x11fc55ed0>,
#  u'relief': <gensim.models.keyedvectors.Vocab at 0x11fc55f10>,
#  u'bottle': <gensim.models.keyedvectors.Vocab at 0x11fba4bd0>,
#  u'mother': <gensim.models.keyedvectors.Vocab at 0x11fc68e10>,
#  u'position': <gensim.models.keyedvectors.Vocab at 0x11fc609d0>,
#  u'drawing': <gensim.models.keyedvectors.Vocab at 0x11f49c7d0>,
#  u'bodies': <gensim.models.keyedvectors.Vocab at 0x11fc55f50>,
#  u'left': <gensim.models.keyedvectors.Vocab at 0x11fb9f290>,
#  u'summer': <gensim.models.keyedvectors.Vocab at 0x11f3e4110>,
#  u'background': <gensim.models.keyedvectors.Vocab at 0x11fb9f3d0>,
#  u'flesh': <gensim.models.keyedvectors.Vocab at 0x11f49c810>,
#  u'money': <gensim.models.keyedvectors.Vocab at 0x11fba4c10>,
#  u'hands': <gensim.models.keyedvectors.Vocab at 0x11fbc5710>,
#  u'rest': <gensim.models.keyedvectors.Vocab at 0x11f3e4150>,
#  u'snow': <gensim.models.keyedvectors.Vocab at 0x11fc68910>,
#  u'front': <gensim.models.keyedvectors.Vocab at 0x11fbc5750>,
#  u'shape': <gensim.models.keyedvectors.Vocab at 0x11fc4ee50>,
#  u'kill': <gensim.models.keyedvectors.Vocab at 0x11f3cf050>,
#  u'rooms': <gensim.models.keyedvectors.Vocab at 0x11f49c850>,
#  u'human': <gensim.models.keyedvectors.Vocab at 0x11fb9f2d0>,
#  u'touch': <gensim.models.keyedvectors.Vocab at 0x11f4bd990>,
#  u'yes': <gensim.models.keyedvectors.Vocab at 0x11fb9f310>,
#  u'yet': <gensim.models.keyedvectors.Vocab at 0x11fb9f350>,
#  u'death': <gensim.models.keyedvectors.Vocab at 0x11f4bd9d0>,
#  u'got': <gensim.models.keyedvectors.Vocab at 0x11fc68650>,
#  u'instance': <gensim.models.keyedvectors.Vocab at 0x11fbc5a10>,
#  u'thinking': <gensim.models.keyedvectors.Vocab at 0x11f4bda10>,
#  u'danger': <gensim.models.keyedvectors.Vocab at 0x11fbc5450>,
#  u'seems': <gensim.models.keyedvectors.Vocab at 0x11fc55fd0>,
#  u'except': <gensim.models.keyedvectors.Vocab at 0x11fc72050>,
#  u'hall': <gensim.models.keyedvectors.Vocab at 0x11f4bd150>,
#  u'wall': <gensim.models.keyedvectors.Vocab at 0x11fc5cd50>,
#  u'add': <gensim.models.keyedvectors.Vocab at 0x11fc60a50>,
#  u'spread': <gensim.models.keyedvectors.Vocab at 0x11f499750>,
#  u'easy': <gensim.models.keyedvectors.Vocab at 0x11f499590>,
#  u'wet': <gensim.models.keyedvectors.Vocab at 0x11f4b6b10>,
#  u'save': <gensim.models.keyedvectors.Vocab at 0x11fb9f390>,
#  u'hat': <gensim.models.keyedvectors.Vocab at 0x11edb2b10>,
#  u'surprised': <gensim.models.keyedvectors.Vocab at 0x11f3cf550>,
#  u'joke': <gensim.models.keyedvectors.Vocab at 0x11fc60750>,
#  u'real': <gensim.models.keyedvectors.Vocab at 0x11f4bda50>,
#  u'shoulder': <gensim.models.keyedvectors.Vocab at 0x11fb9f410>,
#  u'around': <gensim.models.keyedvectors.Vocab at 0x11f3e4190>,
#  u'read': <gensim.models.keyedvectors.Vocab at 0x11f3cf490>,
#  u'big': <gensim.models.keyedvectors.Vocab at 0x11fc4ef10>,
#  u'couple': <gensim.models.keyedvectors.Vocab at 0x11f3cf590>,
#  u'possible': <gensim.models.keyedvectors.Vocab at 0x11edb2e90>,
#  u'wives': <gensim.models.keyedvectors.Vocab at 0x11f3cf5d0>,
#  u'dark': <gensim.models.keyedvectors.Vocab at 0x11f3e41d0>,
#  u'possibly': <gensim.models.keyedvectors.Vocab at 0x11edb2bd0>,
#  u'game': <gensim.models.keyedvectors.Vocab at 0x11f4b6d90>,
#  u'five': <gensim.models.keyedvectors.Vocab at 0x11f49c8d0>,
#  u'know': <gensim.models.keyedvectors.Vocab at 0x11fc4f050>,
#  u'birth': <gensim.models.keyedvectors.Vocab at 0x11edb2b90>,
#  u'desk': <gensim.models.keyedvectors.Vocab at 0x11f49c910>,
#  u'press': <gensim.models.keyedvectors.Vocab at 0x11fc4f090>,
#  u'world': <gensim.models.keyedvectors.Vocab at 0x11f3e4210>,
#  u'shadow': <gensim.models.keyedvectors.Vocab at 0x11edb2890>,
#  u'paint': <gensim.models.keyedvectors.Vocab at 0x11fc4e890>,
#  u'alma': <gensim.models.keyedvectors.Vocab at 0x11fc4e150>,
#  u'desire': <gensim.models.keyedvectors.Vocab at 0x11edb2850>,
#  u'knock': <gensim.models.keyedvectors.Vocab at 0x11fc4ef50>,
#  u'martha': <gensim.models.keyedvectors.Vocab at 0x11fc5c8d0>,
#  u'necessary': <gensim.models.keyedvectors.Vocab at 0x11fbc5e50>,
#  u'like': <gensim.models.keyedvectors.Vocab at 0x11fc60b10>,
#  u'lost': <gensim.models.keyedvectors.Vocab at 0x11fbc5e90>,
#  u'moira': <gensim.models.keyedvectors.Vocab at 0x11f4b6dd0>,
#  u'spine': <gensim.models.keyedvectors.Vocab at 0x11f3cf650>,
#  u'sofa': <gensim.models.keyedvectors.Vocab at 0x11fc60b50>,
#  u'ring': <gensim.models.keyedvectors.Vocab at 0x11f4bd390>,
#  u'commanders': <gensim.models.keyedvectors.Vocab at 0x11fc5c090>,
#  u'author': <gensim.models.keyedvectors.Vocab at 0x11fc55e90>,
#  u'heart': <gensim.models.keyedvectors.Vocab at 0x11fc5c410>,
#  u'remind': <gensim.models.keyedvectors.Vocab at 0x11f403050>,
#  u'continue': <gensim.models.keyedvectors.Vocab at 0x11f3cf690>,
#  u'steps': <gensim.models.keyedvectors.Vocab at 0x11f403090>,
#  u'nose': <gensim.models.keyedvectors.Vocab at 0x11fbc5290>,
#  u'night': <gensim.models.keyedvectors.Vocab at 0x11f499790>,
#  u'become': <gensim.models.keyedvectors.Vocab at 0x11f49c950>,
#  u'fault': <gensim.models.keyedvectors.Vocab at 0x11fc68c10>,
#  u'soft': <gensim.models.keyedvectors.Vocab at 0x11fc60b90>,
#  u'signal': <gensim.models.keyedvectors.Vocab at 0x11f4b6e10>,
#  u'right': <gensim.models.keyedvectors.Vocab at 0x11f4030d0>,
#  u'old': <gensim.models.keyedvectors.Vocab at 0x11f403110>,
#  u'often': <gensim.models.keyedvectors.Vocab at 0x11fc4ef90>,
#  u'crowd': <gensim.models.keyedvectors.Vocab at 0x11f403150>,
#  u'people': <gensim.models.keyedvectors.Vocab at 0x11f403450>,
#  u'understand': <gensim.models.keyedvectors.Vocab at 0x11fc4ecd0>,
#  u'nobody': <gensim.models.keyedvectors.Vocab at 0x11fc60550>,
#  u'begin': <gensim.models.keyedvectors.Vocab at 0x11f4bd5d0>,
#  u'alive': <gensim.models.keyedvectors.Vocab at 0x11fbc5110>,
#  u'hair': <gensim.models.keyedvectors.Vocab at 0x11fc60bd0>,
#  u'lips': <gensim.models.keyedvectors.Vocab at 0x11f4b6e90>,
#  u'sure': <gensim.models.keyedvectors.Vocab at 0x11fc55a50>,
#  u'however': <gensim.models.keyedvectors.Vocab at 0x11fc68b50>,
#  u'story': <gensim.models.keyedvectors.Vocab at 0x11fc72ad0>,
#  u'sight': <gensim.models.keyedvectors.Vocab at 0x11f3cf6d0>,
#  u'mirror': <gensim.models.keyedvectors.Vocab at 0x11fc60050>,
#  u'dear': <gensim.models.keyedvectors.Vocab at 0x11fb9f510>,
#  u'home': <gensim.models.keyedvectors.Vocab at 0x11fbc5fd0>,
#  u'sit': <gensim.models.keyedvectors.Vocab at 0x11fc5c5d0>,
#  u'pale': <gensim.models.keyedvectors.Vocab at 0x11f3cf710>,
#  u'leaf': <gensim.models.keyedvectors.Vocab at 0x11fc4f0d0>,
#  u'lead': <gensim.models.keyedvectors.Vocab at 0x11fc4f110>,
#  u'purple': <gensim.models.keyedvectors.Vocab at 0x11f4997d0>,
#  u'avoid': <gensim.models.keyedvectors.Vocab at 0x11f49c990>,
#  u'lean': <gensim.models.keyedvectors.Vocab at 0x11fc4f150>,
#  u'token': <gensim.models.keyedvectors.Vocab at 0x11fc4e5d0>,
#  u'stops': <gensim.models.keyedvectors.Vocab at 0x11f3cf950>,
#  u'moon': <gensim.models.keyedvectors.Vocab at 0x11fc72090>,
#  u'everything': <gensim.models.keyedvectors.Vocab at 0x11fc68f90>,
#  u'pen': <gensim.models.keyedvectors.Vocab at 0x11fc60090>,
#  u'asking': <gensim.models.keyedvectors.Vocab at 0x11f499810>,
#  u'cloud': <gensim.models.keyedvectors.Vocab at 0x11fc600d0>,
#  u'wife': <gensim.models.keyedvectors.Vocab at 0x11fc72290>,
#  u'christmas': <gensim.models.keyedvectors.Vocab at 0x11fc68fd0>,
#  u'knife': <gensim.models.keyedvectors.Vocab at 0x11fba4cd0>,
#  u'either': <gensim.models.keyedvectors.Vocab at 0x11fba4c50>,
#  u'says': <gensim.models.keyedvectors.Vocab at 0x11fc55410>,
#  u'noise': <gensim.models.keyedvectors.Vocab at 0x11fc60c10>,
#  u'run': <gensim.models.keyedvectors.Vocab at 0x11f4b6ed0>,
#  u'cora': <gensim.models.keyedvectors.Vocab at 0x11fc55050>,
#  u'power': <gensim.models.keyedvectors.Vocab at 0x11f3e4250>,
#  u'slight': <gensim.models.keyedvectors.Vocab at 0x11fc60c50>,
#  u'lose': <gensim.models.keyedvectors.Vocab at 0x11fbc5ed0>,
#  u'rug': <gensim.models.keyedvectors.Vocab at 0x11f4b6f10>,
#  u'stem': <gensim.models.keyedvectors.Vocab at 0x11f4b6f50>,
#  u'broken': <gensim.models.keyedvectors.Vocab at 0x11fba4d10>,
#  u'step': <gensim.models.keyedvectors.Vocab at 0x11f4b6f90>,
#  u'nowhere': <gensim.models.keyedvectors.Vocab at 0x11f3cf750>,
#  u'although': <gensim.models.keyedvectors.Vocab at 0x11fc60c90>,
#  ...}

# %%
#include phrases
bigramer = gensim.models.Phrases(sentences)
w2vmodel = w2v.Word2Vec(bigramer[sentences],
    sg=1, #algorithm: skip-gram
    seed=seed,#random no. generator
    workers=num_workers, #number of worker threads
    size=num_features, #dimensions of word vectors
    min_count=min_word_count,#minimun occurences words
    window=context_size,#size of "context" around a word
    sample=downsample, #downsample setting
    #negative = 10 #negative sampling 
)

w2vmodel.build_vocab(sentences,update=True)
w2vmodel.wv.vocab
# Out:
# 2017-12-14 18:39:11,914 : INFO : collecting all words and their counts
# 2017-12-14 18:39:11,917 : INFO : PROGRESS: at sentence #0, processed 0 words and 0 word types
# 2017-12-14 18:39:12,190 : INFO : collected 39755 word types from a corpus of 43479 words (unigram + bigrams) and 8099 sentences
# 2017-12-14 18:39:12,192 : INFO : using 39755 counts as vocab in Phrases<0 vocab, min_count=5, threshold=10.0, max_vocab_size=40000000>
# 2017-12-14 18:39:12,197 : INFO : collecting all words and their counts
# 2017-12-14 18:39:12,199 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2017-12-14 18:39:12,795 : INFO : collected 8354 word types from a corpus of 42873 raw words and 8099 sentences
# 2017-12-14 18:39:12,797 : INFO : Loading a fresh vocabulary
# 2017-12-14 18:39:12,820 : INFO : min_count=7 retains 1173 unique words (14% of original 8354, drops 7181)
# 2017-12-14 18:39:12,822 : INFO : min_count=7 leaves 29932 word corpus (69% of original 42873, drops 12941)
# 2017-12-14 18:39:12,842 : INFO : deleting the raw counts dictionary of 8354 items
# 2017-12-14 18:39:12,846 : INFO : sample=0.001 downsamples 61 most-common words
# 2017-12-14 18:39:12,848 : INFO : downsampling leaves estimated 26089 word corpus (87.2% of prior 29932)
# 2017-12-14 18:39:12,850 : INFO : estimated required memory for 1173 words and 300 dimensions: 3401700 bytes
# 2017-12-14 18:39:12,864 : INFO : resetting layer weights
# 2017-12-14 18:39:12,900 : INFO : training model with 4 workers on 1173 vocabulary and 300 features, using sg=1 hs=0 sample=0.001 negative=5 window=7
# 2017-12-14 18:39:12,913 : WARNING : train() called with an empty iterator (if not intended, be sure to provide a corpus that offers restartable iteration = an iterable).
# 2017-12-14 18:39:12,919 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2017-12-14 18:39:12,930 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2017-12-14 18:39:12,934 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2017-12-14 18:39:12,937 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2017-12-14 18:39:12,942 : INFO : training on 0 raw words (0 effective words) took 0.0s, 0 effective words/s
# 2017-12-14 18:39:12,945 : WARNING : under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# 2017-12-14 18:39:12,949 : WARNING : supplied example count (0) did not equal expected count (40495)
# 2017-12-14 18:39:12,952 : INFO : collecting all words and their counts
# 2017-12-14 18:39:12,960 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2017-12-14 18:39:13,024 : INFO : collected 8312 word types from a corpus of 43479 raw words and 8099 sentences
# 2017-12-14 18:39:13,027 : INFO : Updating model with new vocabulary
# 2017-12-14 18:39:13,045 : INFO : New added 1152 unique words (12% of original 9464) and increased the count of 1152 pre-existing words (12% of original 9464)
# 2017-12-14 18:39:13,081 : INFO : deleting the raw counts dictionary of 8312 items
# 2017-12-14 18:39:13,083 : INFO : sample=0.001 downsamples 134 most-common words
# 2017-12-14 18:39:13,085 : INFO : downsampling leaves estimated 53002 word corpus (172.9% of prior 30647)
# 2017-12-14 18:39:13,090 : INFO : estimated required memory for 2304 words and 300 dimensions: 6681600 bytes
# 2017-12-14 18:39:13,099 : INFO : updating layer weights
# {u'salvagings': <gensim.models.keyedvectors.Vocab at 0x11a886550>,
#  u'forget': <gensim.models.keyedvectors.Vocab at 0x11ff1ebd0>,
#  u'chain': <gensim.models.keyedvectors.Vocab at 0x11f591850>,
#  u'white_cotton': <gensim.models.keyedvectors.Vocab at 0x11ff16b50>,
#  u'forbidden': <gensim.models.keyedvectors.Vocab at 0x11ff1ec10>,
#  u'wreath': <gensim.models.keyedvectors.Vocab at 0x11f7bc710>,
#  u'bear': <gensim.models.keyedvectors.Vocab at 0x11ff162d0>,
#  u'yellow': <gensim.models.keyedvectors.Vocab at 0x11fc4f7d0>,
#  u'month': <gensim.models.keyedvectors.Vocab at 0x11ff24990>,
#  u'four': <gensim.models.keyedvectors.Vocab at 0x11fc4f850>,
#  u'known': <gensim.models.keyedvectors.Vocab at 0x11a8b0450>,
#  u'sleep': <gensim.models.keyedvectors.Vocab at 0x11ff16b90>,
#  u'ice': <gensim.models.keyedvectors.Vocab at 0x11ff12c50>,
#  u'hanging': <gensim.models.keyedvectors.Vocab at 0x11ff1b690>,
#  u'go': <gensim.models.keyedvectors.Vocab at 0x11fef6d50>,
#  u'chair': <gensim.models.keyedvectors.Vocab at 0x11f591a50>,
#  u'milk': <gensim.models.keyedvectors.Vocab at 0x11fefc3d0>,
#  u'seemed': <gensim.models.keyedvectors.Vocab at 0x11f7b6450>,
#  u'kitchen_table': <gensim.models.keyedvectors.Vocab at 0x11ff1bcd0>,
#  u'hurry': <gensim.models.keyedvectors.Vocab at 0x11ff16710>,
#  u'tv': <gensim.models.keyedvectors.Vocab at 0x11f7b1050>,
#  u'elizabeth': <gensim.models.keyedvectors.Vocab at 0x11a88f450>,
#  u'flash': <gensim.models.keyedvectors.Vocab at 0x11ff176d0>,
#  u'grass': <gensim.models.keyedvectors.Vocab at 0x11a886f50>,
#  u'young': <gensim.models.keyedvectors.Vocab at 0x11f7b6490>,
#  u'send': <gensim.models.keyedvectors.Vocab at 0x11f7b64d0>,
#  u'suits': <gensim.models.keyedvectors.Vocab at 0x11ff1edd0>,
#  u'finally': <gensim.models.keyedvectors.Vocab at 0x11fefc410>,
#  u'late': <gensim.models.keyedvectors.Vocab at 0x11ff0f0d0>,
#  u'lord': <gensim.models.keyedvectors.Vocab at 0x11ff1b250>,
#  u'sorry': <gensim.models.keyedvectors.Vocab at 0x11fef4e10>,
#  u'women': <gensim.models.keyedvectors.Vocab at 0x11a8a3350>,
#  u'waiting': <gensim.models.keyedvectors.Vocab at 0x11a8a3210>,
#  u'sent': <gensim.models.keyedvectors.Vocab at 0x11f7b6510>,
#  u'carried': <gensim.models.keyedvectors.Vocab at 0x11a88f150>,
#  u'washroom': <gensim.models.keyedvectors.Vocab at 0x11ff249d0>,
#  u'brown': <gensim.models.keyedvectors.Vocab at 0x11ff17710>,
#  u'lack': <gensim.models.keyedvectors.Vocab at 0x11a8b0090>,
#  u'garden': <gensim.models.keyedvectors.Vocab at 0x11f7b6550>,
#  u'sitting': <gensim.models.keyedvectors.Vocab at 0x11ff12090>,
#  u'far': <gensim.models.keyedvectors.Vocab at 0x11a8b0190>,
#  u'blanket': <gensim.models.keyedvectors.Vocab at 0x11f7bc750>,
#  u'none': <gensim.models.keyedvectors.Vocab at 0x11ff1ee90>,
#  u'fat': <gensim.models.keyedvectors.Vocab at 0x11a8b01d0>,
#  u'choice': <gensim.models.keyedvectors.Vocab at 0x11f591610>,
#  u'every': <gensim.models.keyedvectors.Vocab at 0x11ff16c10>,
#  u'fall': <gensim.models.keyedvectors.Vocab at 0x11ff1ec50>,
#  u'telling': <gensim.models.keyedvectors.Vocab at 0x11fef6e10>,
#  u'trouble': <gensim.models.keyedvectors.Vocab at 0x11ff17750>,
#  u'difference': <gensim.models.keyedvectors.Vocab at 0x11ff1ec90>,
#  u'fireplace': <gensim.models.keyedvectors.Vocab at 0x11ff16c50>,
#  u'wipe': <gensim.models.keyedvectors.Vocab at 0x11f7b6590>,
#  u'minute': <gensim.models.keyedvectors.Vocab at 0x11f591310>,
#  u'school': <gensim.models.keyedvectors.Vocab at 0x11ff16c90>,
#  u'went': <gensim.models.keyedvectors.Vocab at 0x11ff28450>,
#  u'stiff': <gensim.models.keyedvectors.Vocab at 0x11fef6e50>,
#  u'wooden': <gensim.models.keyedvectors.Vocab at 0x11ff1b890>,
#  u'killed': <gensim.models.keyedvectors.Vocab at 0x11fef49d0>,
#  u'list': <gensim.models.keyedvectors.Vocab at 0x11a8b0250>,
#  u'leave': <gensim.models.keyedvectors.Vocab at 0x11f591590>,
#  u'married': <gensim.models.keyedvectors.Vocab at 0x11a8a3a50>,
#  u'small': <gensim.models.keyedvectors.Vocab at 0x11f7b1110>,
#  u'sidewalk': <gensim.models.keyedvectors.Vocab at 0x11ff17790>,
#  u'round': <gensim.models.keyedvectors.Vocab at 0x11fefc490>,
#  u'clothes': <gensim.models.keyedvectors.Vocab at 0x11fef4e50>,
#  u'enjoy': <gensim.models.keyedvectors.Vocab at 0x11ff16cd0>,
#  u'upper': <gensim.models.keyedvectors.Vocab at 0x11a8b07d0>,
#  u'work': <gensim.models.keyedvectors.Vocab at 0x11f7bca10>,
#  u'force': <gensim.models.keyedvectors.Vocab at 0x11fef4e90>,
#  u'ten': <gensim.models.keyedvectors.Vocab at 0x11a8b0290>,
#  u'tired': <gensim.models.keyedvectors.Vocab at 0x11ff1b850>,
#  u'sigh': <gensim.models.keyedvectors.Vocab at 0x11f591a10>,
#  u'skin': <gensim.models.keyedvectors.Vocab at 0x11fefc390>,
#  u'sign': <gensim.models.keyedvectors.Vocab at 0x11f591ed0>,
#  u'past': <gensim.models.keyedvectors.Vocab at 0x11f7b1150>,
#  u'fold': <gensim.models.keyedvectors.Vocab at 0x11a8a31d0>,
#  u'second': <gensim.models.keyedvectors.Vocab at 0x11ff1b2d0>,
#  u'street': <gensim.models.keyedvectors.Vocab at 0x11ff16d10>,
#  u'nolite_te': <gensim.models.keyedvectors.Vocab at 0x11a8b0d50>,
#  u'dried': <gensim.models.keyedvectors.Vocab at 0x11a886190>,
#  u'pass': <gensim.models.keyedvectors.Vocab at 0x11f7b1190>,
#  u'eating': <gensim.models.keyedvectors.Vocab at 0x11fef6f10>,
#  u'judd': <gensim.models.keyedvectors.Vocab at 0x11a886310>,
#  u'click': <gensim.models.keyedvectors.Vocab at 0x11fef6ed0>,
#  u'machines': <gensim.models.keyedvectors.Vocab at 0x11f7bc7d0>,
#  u'cora': <gensim.models.keyedvectors.Vocab at 0x11ff12d10>,
#  u'even': <gensim.models.keyedvectors.Vocab at 0x11fef4f10>,
#  u'material': <gensim.models.keyedvectors.Vocab at 0x11a8a36d0>,
#  u'stood': <gensim.models.keyedvectors.Vocab at 0x11ff1ed50>,
#  u'appear': <gensim.models.keyedvectors.Vocab at 0x11ff17810>,
#  u'clock': <gensim.models.keyedvectors.Vocab at 0x11f7b11d0>,
#  u'giving': <gensim.models.keyedvectors.Vocab at 0x11ff0fe10>,
#  u'sun': <gensim.models.keyedvectors.Vocab at 0x11a8b0310>,
#  u'stool': <gensim.models.keyedvectors.Vocab at 0x11ff1ed90>,
#  u'fingers': <gensim.models.keyedvectors.Vocab at 0x11ff1bd50>,
#  u'uniform': <gensim.models.keyedvectors.Vocab at 0x11ff17850>,
#  u'business': <gensim.models.keyedvectors.Vocab at 0x11ff24690>,
#  u'public': <gensim.models.keyedvectors.Vocab at 0x11a8b0350>,
#  u'hungry': <gensim.models.keyedvectors.Vocab at 0x11a886810>,
#  u'reconstruction': <gensim.models.keyedvectors.Vocab at 0x11f7bc810>,
#  u'sideways': <gensim.models.keyedvectors.Vocab at 0x11fefcc10>,
#  u'new': <gensim.models.keyedvectors.Vocab at 0x11fef4f50>,
#  u'falling': <gensim.models.keyedvectors.Vocab at 0x11f591410>,
#  u'carpet': <gensim.models.keyedvectors.Vocab at 0x11f7bc850>,
#  u'ever': <gensim.models.keyedvectors.Vocab at 0x11fef4f90>,
#  u'bird': <gensim.models.keyedvectors.Vocab at 0x11f7b65d0>,
#  u'filled': <gensim.models.keyedvectors.Vocab at 0x11fefc510>,
#  u'told': <gensim.models.keyedvectors.Vocab at 0x11f7bc890>,
#  u'body': <gensim.models.keyedvectors.Vocab at 0x11ff0fe50>,
#  u'football': <gensim.models.keyedvectors.Vocab at 0x11ff12f50>,
#  u'full': <gensim.models.keyedvectors.Vocab at 0x11f7b1210>,
#  u'leg': <gensim.models.keyedvectors.Vocab at 0x11f7b6610>,
#  u'guardian': <gensim.models.keyedvectors.Vocab at 0x11fefc550>,
#  u'men': <gensim.models.keyedvectors.Vocab at 0x11ff1bc10>,
#  u'water': <gensim.models.keyedvectors.Vocab at 0x11a886250>,
#  u'believed': <gensim.models.keyedvectors.Vocab at 0x11f591d10>,
#  u'field': <gensim.models.keyedvectors.Vocab at 0x11ff1ead0>,
#  u'apartment': <gensim.models.keyedvectors.Vocab at 0x11a8b00d0>,
#  u'let': <gensim.models.keyedvectors.Vocab at 0x11f7b1c90>,
#  u'sink': <gensim.models.keyedvectors.Vocab at 0x11ff0fed0>,
#  u'making': <gensim.models.keyedvectors.Vocab at 0x11fefc750>,
#  u'alone': <gensim.models.keyedvectors.Vocab at 0x11f591c90>,
#  u'path': <gensim.models.keyedvectors.Vocab at 0x11ff16e10>,
#  u'along': <gensim.models.keyedvectors.Vocab at 0x11f591c10>,
#  u'ceiling': <gensim.models.keyedvectors.Vocab at 0x11ff12550>,
#  u'change': <gensim.models.keyedvectors.Vocab at 0x11ff17890>,
#  u'wait': <gensim.models.keyedvectors.Vocab at 0x11fefc590>,
#  u'dry': <gensim.models.keyedvectors.Vocab at 0x11ff28050>,
#  u'boy': <gensim.models.keyedvectors.Vocab at 0x11fefc610>,
#  u'great': <gensim.models.keyedvectors.Vocab at 0x11f7b6650>,
#  u'one_another': <gensim.models.keyedvectors.Vocab at 0x11a8a3250>,
#  u'daughter': <gensim.models.keyedvectors.Vocab at 0x11f7bc8d0>,
#  u'colored': <gensim.models.keyedvectors.Vocab at 0x11ff24ad0>,
#  u'thirty': <gensim.models.keyedvectors.Vocab at 0x11a886290>,
#  u'study': <gensim.models.keyedvectors.Vocab at 0x11f7bc910>,
#  u'changed': <gensim.models.keyedvectors.Vocab at 0x11ff16e50>,
#  u'wherever': <gensim.models.keyedvectors.Vocab at 0x11f5919d0>,
#  u'extreme': <gensim.models.keyedvectors.Vocab at 0x11ff0ff50>,
#  u'leaving': <gensim.models.keyedvectors.Vocab at 0x11a8a3290>,
#  u'put_arm': <gensim.models.keyedvectors.Vocab at 0x11a8a3750>,
#  u'smoke': <gensim.models.keyedvectors.Vocab at 0x11f7bc950>,
#  u'pick': <gensim.models.keyedvectors.Vocab at 0x11f7b1250>,
#  u'usually': <gensim.models.keyedvectors.Vocab at 0x11ff178d0>,
#  u'opinion': <gensim.models.keyedvectors.Vocab at 0x11f7b6690>,
#  u'unknown': <gensim.models.keyedvectors.Vocab at 0x11a8a3790>,
#  u'apart': <gensim.models.keyedvectors.Vocab at 0x11ff12b90>,
#  u'point': <gensim.models.keyedvectors.Vocab at 0x11ff0f850>,
#  u'control': <gensim.models.keyedvectors.Vocab at 0x11fef4110>,
#  u'bare': <gensim.models.keyedvectors.Vocab at 0x11a8b0bd0>,
#  u'love': <gensim.models.keyedvectors.Vocab at 0x11f591490>,
#  u'family': <gensim.models.keyedvectors.Vocab at 0x11ff24b10>,
#  u'extra': <gensim.models.keyedvectors.Vocab at 0x11ff17910>,
#  u'suddenly': <gensim.models.keyedvectors.Vocab at 0x11a8b0390>,
#  u'merely': <gensim.models.keyedvectors.Vocab at 0x11fefc690>,
#  u'prefer': <gensim.models.keyedvectors.Vocab at 0x11f591a90>,
#  u'private': <gensim.models.keyedvectors.Vocab at 0x11f7b60d0>,
#  u'brought': <gensim.models.keyedvectors.Vocab at 0x11ff1b9d0>,
#  u'put': <gensim.models.keyedvectors.Vocab at 0x11ff24fd0>,
#  u'fake': <gensim.models.keyedvectors.Vocab at 0x11f591890>,
#  u'perhaps': <gensim.models.keyedvectors.Vocab at 0x11a8a3e50>,
#  u'janine': <gensim.models.keyedvectors.Vocab at 0x11ff28090>,
#  u'sugar': <gensim.models.keyedvectors.Vocab at 0x11ff28850>,
#  u'singing': <gensim.models.keyedvectors.Vocab at 0x11fef6f90>,
#  u'egg': <gensim.models.keyedvectors.Vocab at 0x11ff24cd0>,
#  u'cloud': <gensim.models.keyedvectors.Vocab at 0x11ff0fc90>,
#  u'standing': <gensim.models.keyedvectors.Vocab at 0x11f7b66d0>,
#  u'use': <gensim.models.keyedvectors.Vocab at 0x11ff0fcd0>,
#  u'eye': <gensim.models.keyedvectors.Vocab at 0x11ff1ee10>,
#  u'working': <gensim.models.keyedvectors.Vocab at 0x11f591e90>,
#  u'army': <gensim.models.keyedvectors.Vocab at 0x11ff280d0>,
#  u'remains': <gensim.models.keyedvectors.Vocab at 0x11fef6fd0>,
#  u'chairs': <gensim.models.keyedvectors.Vocab at 0x11fef6990>,
#  u'lying': <gensim.models.keyedvectors.Vocab at 0x11a8b0b10>,
#  u'give': <gensim.models.keyedvectors.Vocab at 0x11ff28290>,
#  u'arms': <gensim.models.keyedvectors.Vocab at 0x11ff28110>,
#  u'next': <gensim.models.keyedvectors.Vocab at 0x11f7b6710>,
#  u'live': <gensim.models.keyedvectors.Vocab at 0x11ff17950>,
#  u'doubt': <gensim.models.keyedvectors.Vocab at 0x11f7b6750>,
#  u'music': <gensim.models.keyedvectors.Vocab at 0x11ff1b550>,
#  u'calm': <gensim.models.keyedvectors.Vocab at 0x11ff28190>,
#  u'passport': <gensim.models.keyedvectors.Vocab at 0x11ff1b750>,
#  u'teeth': <gensim.models.keyedvectors.Vocab at 0x11fefc350>,
#  u'taken': <gensim.models.keyedvectors.Vocab at 0x11ff24b90>,
#  u'black': <gensim.models.keyedvectors.Vocab at 0x11ff1e190>,
#  u'oh_god': <gensim.models.keyedvectors.Vocab at 0x11f7bc990>,
#  u'tell': <gensim.models.keyedvectors.Vocab at 0x11ff281d0>,
#  u'today': <gensim.models.keyedvectors.Vocab at 0x11a8862d0>,
#  u'phone': <gensim.models.keyedvectors.Vocab at 0x11ff16f10>,
#  u'breathe': <gensim.models.keyedvectors.Vocab at 0x11ff16ed0>,
#  u'flat': <gensim.models.keyedvectors.Vocab at 0x11ff17550>,
#  u'entrance': <gensim.models.keyedvectors.Vocab at 0x11ff179d0>,
#  u'searchlight': <gensim.models.keyedvectors.Vocab at 0x11a8b0490>,
#  u'door': <gensim.models.keyedvectors.Vocab at 0x11f7b1290>,
#  u'knows': <gensim.models.keyedvectors.Vocab at 0x11a8b0410>,
#  u'afford': <gensim.models.keyedvectors.Vocab at 0x11f591f10>,
#  u'waterford': <gensim.models.keyedvectors.Vocab at 0x11ff0fdd0>,
#  u'ofwarren': <gensim.models.keyedvectors.Vocab at 0x11fefc0d0>,
#  u'hurt': <gensim.models.keyedvectors.Vocab at 0x11ff1b490>,
#  u'glass': <gensim.models.keyedvectors.Vocab at 0x11ff1ba10>,
#  u'warm': <gensim.models.keyedvectors.Vocab at 0x11ff28210>,
#  u'smile': <gensim.models.keyedvectors.Vocab at 0x11f7b1090>,
#  u'baby': <gensim.models.keyedvectors.Vocab at 0x11f7b6790>,
#  u'hole': <gensim.models.keyedvectors.Vocab at 0x11ff1bbd0>,
#  u'hold': <gensim.models.keyedvectors.Vocab at 0x11ff1ba50>,
#  u'effort': <gensim.models.keyedvectors.Vocab at 0x11fefc6d0>,
#  u'must': <gensim.models.keyedvectors.Vocab at 0x11ff16f50>,
#  u'worst': <gensim.models.keyedvectors.Vocab at 0x11a8b0210>,
#  u'honey': <gensim.models.keyedvectors.Vocab at 0x11ff282d0>,
#  u'keeping': <gensim.models.keyedvectors.Vocab at 0x11f7b12d0>,
#  u'wool': <gensim.models.keyedvectors.Vocab at 0x11a886890>,
#  u'word': <gensim.models.keyedvectors.Vocab at 0x11f7bc9d0>,
#  u'room': <gensim.models.keyedvectors.Vocab at 0x11ff28250>,
#  u'hour': <gensim.models.keyedvectors.Vocab at 0x11a886090>,
#  u'drawer': <gensim.models.keyedvectors.Vocab at 0x11fefc790>,
#  u'car': <gensim.models.keyedvectors.Vocab at 0x11ff17a10>,
#  u'pretend': <gensim.models.keyedvectors.Vocab at 0x11f591cd0>,
#  u'soul': <gensim.models.keyedvectors.Vocab at 0x11fefc710>,
#  u'worn': <gensim.models.keyedvectors.Vocab at 0x11f7bca50>,
#  u'cat': <gensim.models.keyedvectors.Vocab at 0x11ff17a50>,
#  u'strain': <gensim.models.keyedvectors.Vocab at 0x11ff1eed0>,
#  u'anywhere': <gensim.models.keyedvectors.Vocab at 0x11a8a3410>,
#  u'thin': <gensim.models.keyedvectors.Vocab at 0x11f7b67d0>,
#  u'praise': <gensim.models.keyedvectors.Vocab at 0x11ff16050>,
#  u'elbow': <gensim.models.keyedvectors.Vocab at 0x11f7bca90>,
#  u'pulling': <gensim.models.keyedvectors.Vocab at 0x11fef4150>,
#  u'laughter': <gensim.models.keyedvectors.Vocab at 0x11a886350>,
#  u'history': <gensim.models.keyedvectors.Vocab at 0x11ff24c10>,
#  u'beautiful': <gensim.models.keyedvectors.Vocab at 0x11f7b1310>,
#  u'meant': <gensim.models.keyedvectors.Vocab at 0x11fef6e90>,
#  u'front_door': <gensim.models.keyedvectors.Vocab at 0x11ff1ef10>,
#  u'tap': <gensim.models.keyedvectors.Vocab at 0x11ff0ff90>,
#  u'bent': <gensim.models.keyedvectors.Vocab at 0x11f7b6810>,
#  u'figure': <gensim.models.keyedvectors.Vocab at 0x11a886390>,
#  u'pauses': <gensim.models.keyedvectors.Vocab at 0x11ff17a90>,
#  u'household': <gensim.models.keyedvectors.Vocab at 0x11ff1bc90>,
#  u'allowed': <gensim.models.keyedvectors.Vocab at 0x11f591fd0>,
#  u'table': <gensim.models.keyedvectors.Vocab at 0x11a8a3cd0>,
#  u'days': <gensim.models.keyedvectors.Vocab at 0x11ff12450>,
#  u'high': <gensim.models.keyedvectors.Vocab at 0x11f7b6850>,
#  u'heard': <gensim.models.keyedvectors.Vocab at 0x11ff17ad0>,
#  u'stroke': <gensim.models.keyedvectors.Vocab at 0x11a8a33d0>,
#  u'woman': <gensim.models.keyedvectors.Vocab at 0x11a8b0110>,
#  u'chin': <gensim.models.keyedvectors.Vocab at 0x11ff17b10>,
#  u'road': <gensim.models.keyedvectors.Vocab at 0x11ff1e910>,
#  u'slip': <gensim.models.keyedvectors.Vocab at 0x11f7b6890>,
#  u'sense': <gensim.models.keyedvectors.Vocab at 0x11f7b1350>,
#  u'sharp': <gensim.models.keyedvectors.Vocab at 0x11ff1ef50>,
#  u'keep': <gensim.models.keyedvectors.Vocab at 0x11ff16f90>,
#  u'dress': <gensim.models.keyedvectors.Vocab at 0x11f7b13d0>,
#  u'rape': <gensim.models.keyedvectors.Vocab at 0x11a8a3490>,
#  u'risk': <gensim.models.keyedvectors.Vocab at 0x11ff16bd0>,
#  u'pink': <gensim.models.keyedvectors.Vocab at 0x11fefc7d0>,
#  u'huge': <gensim.models.keyedvectors.Vocab at 0x11f7b1410>,
#  u'siren': <gensim.models.keyedvectors.Vocab at 0x11ff1ef90>,
#  u'end': <gensim.models.keyedvectors.Vocab at 0x11ff12050>,
#  u'winter': <gensim.models.keyedvectors.Vocab at 0x11f591d90>,
#  u'turn': <gensim.models.keyedvectors.Vocab at 0x11a886590>,
#  u'rather': <gensim.models.keyedvectors.Vocab at 0x11a8b04d0>,
#  u'skirt': <gensim.models.keyedvectors.Vocab at 0x11fef41d0>,
#  u'watching': <gensim.models.keyedvectors.Vocab at 0x11a8a3990>,
#  u'dinner': <gensim.models.keyedvectors.Vocab at 0x11a8863d0>,
#  u'stayed': <gensim.models.keyedvectors.Vocab at 0x11ff24c50>,
#  u'arrangement': <gensim.models.keyedvectors.Vocab at 0x11fef4210>,
#  u'machine': <gensim.models.keyedvectors.Vocab at 0x11ff1b210>,
#  u'hot': <gensim.models.keyedvectors.Vocab at 0x11ff1bb50>,
#  u'animal': <gensim.models.keyedvectors.Vocab at 0x11f7b68d0>,
#  u'luke': <gensim.models.keyedvectors.Vocab at 0x11ff0f710>,
#  u'answer': <gensim.models.keyedvectors.Vocab at 0x11ff28310>,
#  u'gate': <gensim.models.keyedvectors.Vocab at 0x11ff120d0>,
#  u'ordinary': <gensim.models.keyedvectors.Vocab at 0x11f7bcad0>,
#  u'stand': <gensim.models.keyedvectors.Vocab at 0x11a886e90>,
#  u'ceremony': <gensim.models.keyedvectors.Vocab at 0x11ff16fd0>,
#  u'cupboard': <gensim.models.keyedvectors.Vocab at 0x11a8a3550>,
#  u'intended': <gensim.models.keyedvectors.Vocab at 0x11f7b1450>,
#  u'may': <gensim.models.keyedvectors.Vocab at 0x11fefc810>,
#  u'watch': <gensim.models.keyedvectors.Vocab at 0x11ff12710>,
#  u'began': <gensim.models.keyedvectors.Vocab at 0x11a8b0550>,
#  u'tied': <gensim.models.keyedvectors.Vocab at 0x11f7b6910>,
#  u'wrong': <gensim.models.keyedvectors.Vocab at 0x11ff1b310>,
#  u'lay': <gensim.models.keyedvectors.Vocab at 0x11f7bcb10>,
#  u'opening': <gensim.models.keyedvectors.Vocab at 0x11a8a3b90>,
#  u'coming': <gensim.models.keyedvectors.Vocab at 0x11a886610>,
#  u'date': <gensim.models.keyedvectors.Vocab at 0x11f591f90>,
#  u'law': <gensim.models.keyedvectors.Vocab at 0x11f7bcb50>,
#  u'man': <gensim.models.keyedvectors.Vocab at 0x11fefc850>,
#  u'short': <gensim.models.keyedvectors.Vocab at 0x11a8b0510>,
#  u'remember': <gensim.models.keyedvectors.Vocab at 0x11ff17b50>,
#  u'third': <gensim.models.keyedvectors.Vocab at 0x11ff28350>,
#  u'maybe': <gensim.models.keyedvectors.Vocab at 0x11fefc890>,
#  u'counter': <gensim.models.keyedvectors.Vocab at 0x11f7b6950>,
#  u'children': <gensim.models.keyedvectors.Vocab at 0x11ff16dd0>,
#  u'tale': <gensim.models.keyedvectors.Vocab at 0x11a88f490>,
#  u'tulip': <gensim.models.keyedvectors.Vocab at 0x11ff1b410>,
#  u'ones': <gensim.models.keyedvectors.Vocab at 0x11a8a39d0>,
#  u'green': <gensim.models.keyedvectors.Vocab at 0x11f7bcb90>,
#  u'silence': <gensim.models.keyedvectors.Vocab at 0x11fefc8d0>,
#  u'pay': <gensim.models.keyedvectors.Vocab at 0x11ff1e690>,
#  u'basket': <gensim.models.keyedvectors.Vocab at 0x11fefc910>,
#  u'tall': <gensim.models.keyedvectors.Vocab at 0x11fefc950>,
#  u'pulled': <gensim.models.keyedvectors.Vocab at 0x11f591e10>,
#  u'order': <gensim.models.keyedvectors.Vocab at 0x11f7bcbd0>,
#  u'wind': <gensim.models.keyedvectors.Vocab at 0x11ff1bad0>,
#  u'wine': <gensim.models.keyedvectors.Vocab at 0x11ff1bb90>,
#  u'help': <gensim.models.keyedvectors.Vocab at 0x11ff24d10>,
#  u'office': <gensim.models.keyedvectors.Vocab at 0x11f7bcc10>,
#  u'food': <gensim.models.keyedvectors.Vocab at 0x11ff24e50>,
#  u'indeed': <gensim.models.keyedvectors.Vocab at 0x11ff12210>,
#  u'move': <gensim.models.keyedvectors.Vocab at 0x11f7b6990>,
#  u'soon': <gensim.models.keyedvectors.Vocab at 0x11ff24d50>,
#  u'aunt_lydia': <gensim.models.keyedvectors.Vocab at 0x11f7b69d0>,
#  u'years': <gensim.models.keyedvectors.Vocab at 0x11f5914d0>,
#  u'top': <gensim.models.keyedvectors.Vocab at 0x11ff124d0>,
#  u'course': <gensim.models.keyedvectors.Vocab at 0x11f5918d0>,
#  u'paper': <gensim.models.keyedvectors.Vocab at 0x11f7b1510>,
#  u'earth': <gensim.models.keyedvectors.Vocab at 0x11ff12690>,
#  u'costume': <gensim.models.keyedvectors.Vocab at 0x11fef4250>,
#  u'shake': <gensim.models.keyedvectors.Vocab at 0x11fefc9d0>,
#  u'red_dress': <gensim.models.keyedvectors.Vocab at 0x11f7bcc50>,
#  u'hell': <gensim.models.keyedvectors.Vocab at 0x11ff24dd0>,
#  u'smiling': <gensim.models.keyedvectors.Vocab at 0x11f7b1550>,
#  u'level': <gensim.models.keyedvectors.Vocab at 0x11a8860d0>,
#  u'forehead': <gensim.models.keyedvectors.Vocab at 0x11ff12a90>,
#  u'le': <gensim.models.keyedvectors.Vocab at 0x11ff16090>,
#  u'group': <gensim.models.keyedvectors.Vocab at 0x11fef4810>,
#  u'thank': <gensim.models.keyedvectors.Vocab at 0x11fefca10>,
#  u'fit': <gensim.models.keyedvectors.Vocab at 0x11ff1bd10>,
#  u'somewhere': <gensim.models.keyedvectors.Vocab at 0x11f7bcc90>,
#  u'border': <gensim.models.keyedvectors.Vocab at 0x11fef4550>,
#  u'writing': <gensim.models.keyedvectors.Vocab at 0x11ff12150>,
#  u'better': <gensim.models.keyedvectors.Vocab at 0x11ff28390>,
#  u'window': <gensim.models.keyedvectors.Vocab at 0x11ff17bd0>,
#  u'choose': <gensim.models.keyedvectors.Vocab at 0x11a8a3610>,
#  u'van': <gensim.models.keyedvectors.Vocab at 0x11a88f210>,
#  u'orange': <gensim.models.keyedvectors.Vocab at 0x11a8a3650>,
#  u'covered': <gensim.models.keyedvectors.Vocab at 0x11a8a3690>,
#  u'hidden': <gensim.models.keyedvectors.Vocab at 0x11ff1b390>,
#  u'main': <gensim.models.keyedvectors.Vocab at 0x11fefca90>,
#  u'might': <gensim.models.keyedvectors.Vocab at 0x11a8b0610>,
#  u'put_hand': <gensim.models.keyedvectors.Vocab at 0x11ff160d0>,
#  u'said_aunt': <gensim.models.keyedvectors.Vocab at 0x11a886410>,
#  u'coffee': <gensim.models.keyedvectors.Vocab at 0x11f7bccd0>,
#  u'evening': <gensim.models.keyedvectors.Vocab at 0x11ff24e10>,
#  u'somebody': <gensim.models.keyedvectors.Vocab at 0x11ff243d0>,
#  u'tucked': <gensim.models.keyedvectors.Vocab at 0x11fefcad0>,
#  u'nod': <gensim.models.keyedvectors.Vocab at 0x11ff17c10>,
#  u'plaster': <gensim.models.keyedvectors.Vocab at 0x11ff121d0>,
#  u'safe': <gensim.models.keyedvectors.Vocab at 0x11f7bcd10>,
#  u'blessed': <gensim.models.keyedvectors.Vocab at 0x11ff1e950>,
#  u'break': <gensim.models.keyedvectors.Vocab at 0x11f7bcd50>,
#  u'handmaids': <gensim.models.keyedvectors.Vocab at 0x11ff28d10>,
#  u'let_go': <gensim.models.keyedvectors.Vocab at 0x11fefcb50>,
#  u'touching': <gensim.models.keyedvectors.Vocab at 0x11fefcb90>,
#  u'kiss': <gensim.models.keyedvectors.Vocab at 0x11f7b6a10>,
#  u'half': <gensim.models.keyedvectors.Vocab at 0x11ff17c50>,
#  u'foot': <gensim.models.keyedvectors.Vocab at 0x11ff244d0>,
#  u'fear': <gensim.models.keyedvectors.Vocab at 0x11a8a38d0>,
#  u'bath': <gensim.models.keyedvectors.Vocab at 0x11a886490>,
#  u'silver': <gensim.models.keyedvectors.Vocab at 0x11ff1be50>,
#  u'bank': <gensim.models.keyedvectors.Vocab at 0x11f7bcd90>,
#  u'bread': <gensim.models.keyedvectors.Vocab at 0x11f7bcdd0>,
#  u'easily': <gensim.models.keyedvectors.Vocab at 0x11ff0f150>,
#  u'term': <gensim.models.keyedvectors.Vocab at 0x11a8864d0>,
#  u'several': <gensim.models.keyedvectors.Vocab at 0x11ff12ad0>,
#  u'cotton': <gensim.models.keyedvectors.Vocab at 0x11fef6c90>,
#  u'meat': <gensim.models.keyedvectors.Vocab at 0x11ff28410>,
#  u'pregnant': <gensim.models.keyedvectors.Vocab at 0x11ff0f190>,
#  u'always': <gensim.models.keyedvectors.Vocab at 0x11f7b1590>,
#  u'university': <gensim.models.keyedvectors.Vocab at 0x11fef4310>,
#  u'mothers': <gensim.models.keyedvectors.Vocab at 0x11ff1ed10>,
#  u'guard': <gensim.models.keyedvectors.Vocab at 0x11ff16950>,
#  u'lotion': <gensim.models.keyedvectors.Vocab at 0x11a88f410>,
#  u'tear': <gensim.models.keyedvectors.Vocab at 0x11f591d50>,
#  u'slide': <gensim.models.keyedvectors.Vocab at 0x11fef4350>,
#  u'weather': <gensim.models.keyedvectors.Vocab at 0x11a88f1d0>,
#  u'stopped': <gensim.models.keyedvectors.Vocab at 0x11ff24e90>,
#  u'truth': <gensim.models.keyedvectors.Vocab at 0x11f7b6a50>,
#  u'die': <gensim.models.keyedvectors.Vocab at 0x11fefc450>,
#  u'found': <gensim.models.keyedvectors.Vocab at 0x11f7b15d0>,
#  u'beneath': <gensim.models.keyedvectors.Vocab at 0x11f7b6a90>,
#  u'tray': <gensim.models.keyedvectors.Vocab at 0x11a8a3710>,
#  u'side': <gensim.models.keyedvectors.Vocab at 0x11ff28490>,
#  u'bone': <gensim.models.keyedvectors.Vocab at 0x11ff284d0>,
#  u'mean': <gensim.models.keyedvectors.Vocab at 0x11f798d90>,
#  u'heavy': <gensim.models.keyedvectors.Vocab at 0x11ff24ed0>,
#  u'nick': <gensim.models.keyedvectors.Vocab at 0x11a8a30d0>,
#  u'square': <gensim.models.keyedvectors.Vocab at 0x11f156d50>,
#  u'england': <gensim.models.keyedvectors.Vocab at 0x11a886ed0>,
#  u'weight': <gensim.models.keyedvectors.Vocab at 0x11a8b0690>,
#  u'house': <gensim.models.keyedvectors.Vocab at 0x11ff0f250>,
#  u'energy': <gensim.models.keyedvectors.Vocab at 0x11ff0f290>,
#  u'hard': <gensim.models.keyedvectors.Vocab at 0x11ff0f2d0>,
#  u'idea': <gensim.models.keyedvectors.Vocab at 0x11ff0f310>,
#  u'started': <gensim.models.keyedvectors.Vocab at 0x11fef40d0>,
#  u'living': <gensim.models.keyedvectors.Vocab at 0x11a88f3d0>,
#  u'society': <gensim.models.keyedvectors.Vocab at 0x11f7b6ad0>,
#  u'books': <gensim.models.keyedvectors.Vocab at 0x11f7b6b10>,
#  u'gave': <gensim.models.keyedvectors.Vocab at 0x11ff12b50>,
#  u'expect': <gensim.models.keyedvectors.Vocab at 0x11a8b06d0>,
#  u'year': <gensim.models.keyedvectors.Vocab at 0x11ff17cd0>,
#  u'happen': <gensim.models.keyedvectors.Vocab at 0x11ff17d10>,
#  u'beyond': <gensim.models.keyedvectors.Vocab at 0x11ff24f10>,
#  u'sexual': <gensim.models.keyedvectors.Vocab at 0x11ff16110>,
#  u'message': <gensim.models.keyedvectors.Vocab at 0x11ff1ba90>,
#  u'really': <gensim.models.keyedvectors.Vocab at 0x11f7b1650>,
#  u'large': <gensim.models.keyedvectors.Vocab at 0x11f7b10d0>,
#  u'given': <gensim.models.keyedvectors.Vocab at 0x11a886650>,
#  u'flower': <gensim.models.keyedvectors.Vocab at 0x11ff0f350>,
#  u'opened': <gensim.models.keyedvectors.Vocab at 0x11ff17d50>,
#  u'space': <gensim.models.keyedvectors.Vocab at 0x11ff17d90>,
#  u'afraid': <gensim.models.keyedvectors.Vocab at 0x11a8a37d0>,
#  u'god': <gensim.models.keyedvectors.Vocab at 0x11ff12290>,
#  u'tried': <gensim.models.keyedvectors.Vocab at 0x11ff24c90>,
#  u'since': <gensim.models.keyedvectors.Vocab at 0x11ff24950>,
#  u'washed': <gensim.models.keyedvectors.Vocab at 0x11ff122d0>,
#  u'bad': <gensim.models.keyedvectors.Vocab at 0x11ff28950>,
#  u'looking': <gensim.models.keyedvectors.Vocab at 0x11ff17dd0>,
#  u'hear': <gensim.models.keyedvectors.Vocab at 0x11ff12e50>,
#  u'softly': <gensim.models.keyedvectors.Vocab at 0x11ff28990>,
#  u'mayday': <gensim.models.keyedvectors.Vocab at 0x11ff12310>,
#  u'print': <gensim.models.keyedvectors.Vocab at 0x11ff0f390>,
#  u'surprise': <gensim.models.keyedvectors.Vocab at 0x11ff28550>,
#  u'forth': <gensim.models.keyedvectors.Vocab at 0x11f7bce10>,
#  u'red': <gensim.models.keyedvectors.Vocab at 0x11f7bc790>,
#  u'oblong': <gensim.models.keyedvectors.Vocab at 0x11f7b6b50>,
#  u'shut': <gensim.models.keyedvectors.Vocab at 0x11f7b6b90>,
#  u'unless': <gensim.models.keyedvectors.Vocab at 0x11ff16210>,
#  u'turning': <gensim.models.keyedvectors.Vocab at 0x11ff28590>,
#  u'barrier': <gensim.models.keyedvectors.Vocab at 0x11f7bce50>,
#  u'kneel': <gensim.models.keyedvectors.Vocab at 0x11a8a3a90>,
#  u'hang': <gensim.models.keyedvectors.Vocab at 0x11ff17210>,
#  u'little': <gensim.models.keyedvectors.Vocab at 0x11fefcd90>,
#  u'possibility': <gensim.models.keyedvectors.Vocab at 0x11f41a4d0>,
#  u'quite': <gensim.models.keyedvectors.Vocab at 0x11f798590>,
#  u'quick': <gensim.models.keyedvectors.Vocab at 0x11a886110>,
#  u'reason': <gensim.models.keyedvectors.Vocab at 0x11ff24f90>,
#  u'worse': <gensim.models.keyedvectors.Vocab at 0x11a8b0150>,
#  u'surely': <gensim.models.keyedvectors.Vocab at 0x11f7b6bd0>,
#  u'murmur': <gensim.models.keyedvectors.Vocab at 0x11f7b16d0>,
#  u'imagine': <gensim.models.keyedvectors.Vocab at 0x11f7b1710>,
#  u'ask': <gensim.models.keyedvectors.Vocab at 0x11ff24b50>,
#  u'sheet': <gensim.models.keyedvectors.Vocab at 0x11ff17f10>,
#  u'wanted': <gensim.models.keyedvectors.Vocab at 0x11ff12410>,
#  u'beginning': <gensim.models.keyedvectors.Vocab at 0x11ff0f3d0>,
#  u'guy': <gensim.models.keyedvectors.Vocab at 0x11a8b0710>,
#  u'care': <gensim.models.keyedvectors.Vocab at 0x11ff17e10>,
#  u'thrown': <gensim.models.keyedvectors.Vocab at 0x11a8b0750>,
#  u'entirely': <gensim.models.keyedvectors.Vocab at 0x11a88f0d0>,
#  u'nightgown': <gensim.models.keyedvectors.Vocab at 0x11a88f2d0>,
#  u'moment': <gensim.models.keyedvectors.Vocab at 0x11ff0fa10>,
#  u'times': <gensim.models.keyedvectors.Vocab at 0x11fef4390>,
#  u'thing': <gensim.models.keyedvectors.Vocab at 0x11fefcc50>,
#  u'expecting': <gensim.models.keyedvectors.Vocab at 0x11fef6050>,
#  u'silently': <gensim.models.keyedvectors.Vocab at 0x11ff1e290>,
#  u'dangerous': <gensim.models.keyedvectors.Vocab at 0x11ff1e4d0>,
#  u'loud': <gensim.models.keyedvectors.Vocab at 0x11ff285d0>,
#  u'think': <gensim.models.keyedvectors.Vocab at 0x11fefcc90>,
#  u'first': <gensim.models.keyedvectors.Vocab at 0x11fefccd0>,
#  u'blind': <gensim.models.keyedvectors.Vocab at 0x11ff17e50>,
#  u'feel': <gensim.models.keyedvectors.Vocab at 0x11a8b0810>,
#  u'wave': <gensim.models.keyedvectors.Vocab at 0x11fef6dd0>,
#  u'number': <gensim.models.keyedvectors.Vocab at 0x11f7b1750>,
#  u'one': <gensim.models.keyedvectors.Vocab at 0x11f798550>,
#  u'feet': <gensim.models.keyedvectors.Vocab at 0x11a8b0850>,
#  u'hook': <gensim.models.keyedvectors.Vocab at 0x11ff28610>,
#  u'talked': <gensim.models.keyedvectors.Vocab at 0x11fefc4d0>,
#  u'done': <gensim.models.keyedvectors.Vocab at 0x11ff0f410>,
#  u'least': <gensim.models.keyedvectors.Vocab at 0x11ff0f450>,
#  u'another': <gensim.models.keyedvectors.Vocab at 0x11f7bce90>,
#  u'blank': <gensim.models.keyedvectors.Vocab at 0x11a8b0890>,
#  u'carry': <gensim.models.keyedvectors.Vocab at 0x11fefcd50>,
#  u'impossible': <gensim.models.keyedvectors.Vocab at 0x11ff17e90>,
#  u'thick': <gensim.models.keyedvectors.Vocab at 0x11f7bced0>,
#  u'noticed': <gensim.models.keyedvectors.Vocab at 0x11fef4c50>,
#  u'open': <gensim.models.keyedvectors.Vocab at 0x11f7985d0>,
#  u'tomorrow': <gensim.models.keyedvectors.Vocab at 0x11ff1b6d0>,
#  u'city': <gensim.models.keyedvectors.Vocab at 0x11f798610>,
#  u'guess': <gensim.models.keyedvectors.Vocab at 0x11f7b1790>,
#  u'heads': <gensim.models.keyedvectors.Vocab at 0x11f7b17d0>,
#  u'silent': <gensim.models.keyedvectors.Vocab at 0x11ff17f50>,
#  u'service': <gensim.models.keyedvectors.Vocab at 0x11ff1b090>,
#  u'downstairs': <gensim.models.keyedvectors.Vocab at 0x11ff1e9d0>,
#  u'twenty': <gensim.models.keyedvectors.Vocab at 0x11a8b0790>,
#  u'caught': <gensim.models.keyedvectors.Vocab at 0x11ff17f90>,
#  u'girls': <gensim.models.keyedvectors.Vocab at 0x11ff28650>,
#  u'system': <gensim.models.keyedvectors.Vocab at 0x11f7b6c10>,
#  u'elevator': <gensim.models.keyedvectors.Vocab at 0x11f7bcf10>,
#  u'name': <gensim.models.keyedvectors.Vocab at 0x11a886510>,
#  u'checkpoint': <gensim.models.keyedvectors.Vocab at 0x11f7b1810>,
#  u'needed': <gensim.models.keyedvectors.Vocab at 0x11ff1b590>,
#  u'attack': <gensim.models.keyedvectors.Vocab at 0x11fef43d0>,
#  u'station': <gensim.models.keyedvectors.Vocab at 0x11f7b1390>,
#  u'passed': <gensim.models.keyedvectors.Vocab at 0x11a8b0910>,
#  u'tea': <gensim.models.keyedvectors.Vocab at 0x11a8b02d0>,
#  u'free': <gensim.models.keyedvectors.Vocab at 0x11ff12390>,
#  u'white': <gensim.models.keyedvectors.Vocab at 0x11a8866d0>,
#  u'legs': <gensim.models.keyedvectors.Vocab at 0x11ff1bed0>,
#  u'friend': <gensim.models.keyedvectors.Vocab at 0x11ff17fd0>,
#  u'listen': <gensim.models.keyedvectors.Vocab at 0x11ff1b190>,
#  u'back': <gensim.models.keyedvectors.Vocab at 0x11ff0fbd0>,
#  u'curtains': <gensim.models.keyedvectors.Vocab at 0x11ff12510>,
#  u'eyes': <gensim.models.keyedvectors.Vocab at 0x11fefce50>,
#  u'stomach': <gensim.models.keyedvectors.Vocab at 0x11f7b6c50>,
#  u'lot': <gensim.models.keyedvectors.Vocab at 0x11ff24810>,
#  u'behind': <gensim.models.keyedvectors.Vocab at 0x11ff1e150>,
#  u'exactly': <gensim.models.keyedvectors.Vocab at 0x11fef4410>,
#  u'sick': <gensim.models.keyedvectors.Vocab at 0x11a8a3f10>,
#  u'took': <gensim.models.keyedvectors.Vocab at 0x11ff12590>,
#  u'shoulder': <gensim.models.keyedvectors.Vocab at 0x11ff28f50>,
#  u'part': <gensim.models.keyedvectors.Vocab at 0x11ff0f4d0>,
#  u'flowers': <gensim.models.keyedvectors.Vocab at 0x11ff24050>,
#  u'stairs': <gensim.models.keyedvectors.Vocab at 0x11a8b0b50>,
#  u'neck': <gensim.models.keyedvectors.Vocab at 0x11fef4450>,
#  u'steel': <gensim.models.keyedvectors.Vocab at 0x11f7b6c90>,
#  u'wide': <gensim.models.keyedvectors.Vocab at 0x11a886710>,
#  u'television': <gensim.models.keyedvectors.Vocab at 0x11ff24090>,
#  u'hundred': <gensim.models.keyedvectors.Vocab at 0x11fef6090>,
#  u'decided': <gensim.models.keyedvectors.Vocab at 0x11ff289d0>,
#  u'showed': <gensim.models.keyedvectors.Vocab at 0x11ff1b910>,
#  u'double': <gensim.models.keyedvectors.Vocab at 0x11a8b09d0>,
#  u'bother': <gensim.models.keyedvectors.Vocab at 0x11f7b6cd0>,
#  u'older': <gensim.models.keyedvectors.Vocab at 0x11fef6850>,
#  u'tree': <gensim.models.keyedvectors.Vocab at 0x11ff1b710>,
#  u'likely': <gensim.models.keyedvectors.Vocab at 0x11fef4ed0>,
#  u'bed': <gensim.models.keyedvectors.Vocab at 0x11fef4490>,
#  u'matter': <gensim.models.keyedvectors.Vocab at 0x11ff28690>,
#  u'future': <gensim.models.keyedvectors.Vocab at 0x11f798650>,
#  u'store': <gensim.models.keyedvectors.Vocab at 0x11fef6110>,
#  u'historical': <gensim.models.keyedvectors.Vocab at 0x11ff0f810>,
#  u'light': <gensim.models.keyedvectors.Vocab at 0x11a8a3590>,
#  u'anyone': <gensim.models.keyedvectors.Vocab at 0x11fefcdd0>,
#  u'sitting_room': <gensim.models.keyedvectors.Vocab at 0x11fef44d0>,
#  u'feeling': <gensim.models.keyedvectors.Vocab at 0x11ff1b1d0>,
#  u'minor': <gensim.models.keyedvectors.Vocab at 0x11a8b03d0>,
#  u'angel': <gensim.models.keyedvectors.Vocab at 0x11ff240d0>,
#  u'film': <gensim.models.keyedvectors.Vocab at 0x11ff1ea50>,
#  u'turned': <gensim.models.keyedvectors.Vocab at 0x11f798690>,
#  u'gently': <gensim.models.keyedvectors.Vocab at 0x11f7b6d10>,
#  u'thought_might': <gensim.models.keyedvectors.Vocab at 0x11a8b0a10>,
#  u'sad': <gensim.models.keyedvectors.Vocab at 0x11f7986d0>,
#  u'tonight': <gensim.models.keyedvectors.Vocab at 0x11f7b6d50>,
#  u'juice': <gensim.models.keyedvectors.Vocab at 0x11fef6150>,
#  u'say': <gensim.models.keyedvectors.Vocab at 0x11f798710>,
#  u'blond': <gensim.models.keyedvectors.Vocab at 0x11f7b1850>,
#  u'need': <gensim.models.keyedvectors.Vocab at 0x11fef4510>,
#  u'seen': <gensim.models.keyedvectors.Vocab at 0x11ff28750>,
#  u'breakfast': <gensim.models.keyedvectors.Vocab at 0x11ff24110>,
#  u'saw': <gensim.models.keyedvectors.Vocab at 0x11f798750>,
#  u'sat': <gensim.models.keyedvectors.Vocab at 0x11f798790>,
#  u'lie': <gensim.models.keyedvectors.Vocab at 0x11fef6190>,
#  u'breathing': <gensim.models.keyedvectors.Vocab at 0x11a8a3190>,
#  u'speaking': <gensim.models.keyedvectors.Vocab at 0x11fefce10>,
#  u'place': <gensim.models.keyedvectors.Vocab at 0x11a8865d0>,
#  u'able': <gensim.models.keyedvectors.Vocab at 0x11fef4590>,
#  u'aside': <gensim.models.keyedvectors.Vocab at 0x11f7987d0>,
#  u'arm': <gensim.models.keyedvectors.Vocab at 0x11a8b0c10>,
#  u'lit': <gensim.models.keyedvectors.Vocab at 0x11fef61d0>,
#  u'also': <gensim.models.keyedvectors.Vocab at 0x11f7b1890>,
#  u'edge': <gensim.models.keyedvectors.Vocab at 0x11a8b0e90>,
#  u'lip': <gensim.models.keyedvectors.Vocab at 0x11fef6210>,
#  u'take': <gensim.models.keyedvectors.Vocab at 0x11f798810>,
#  u'doors': <gensim.models.keyedvectors.Vocab at 0x11ff1b3d0>,
#  u'wonder': <gensim.models.keyedvectors.Vocab at 0x11ff1e310>,
#  u'lily': <gensim.models.keyedvectors.Vocab at 0x11f7b6d90>,
#  u'soap': <gensim.models.keyedvectors.Vocab at 0x11f7b6dd0>,
#  u'blue': <gensim.models.keyedvectors.Vocab at 0x11ff16d50>,
#  u'play': <gensim.models.keyedvectors.Vocab at 0x11f7b18d0>,
#  u'towards': <gensim.models.keyedvectors.Vocab at 0x11fef6250>,
#  u'pain': <gensim.models.keyedvectors.Vocab at 0x11fefce90>,
#  u'serena': <gensim.models.keyedvectors.Vocab at 0x11ff0f590>,
#  u'normal': <gensim.models.keyedvectors.Vocab at 0x11fefced0>,
#  u'track': <gensim.models.keyedvectors.Vocab at 0x11fefcf10>,
#  u'eggs': <gensim.models.keyedvectors.Vocab at 0x11ff0f5d0>,
#  u'knew': <gensim.models.keyedvectors.Vocab at 0x11f798850>,
#  u'reach': <gensim.models.keyedvectors.Vocab at 0x11a8b0a50>,
#  u'paid': <gensim.models.keyedvectors.Vocab at 0x11fefcf50>,
#  u'cigarette': <gensim.models.keyedvectors.Vocab at 0x11a8b0a90>,
#  u'said': <gensim.models.keyedvectors.Vocab at 0x11ff28a50>,
#  u'mouth': <gensim.models.keyedvectors.Vocab at 0x11ff1bc50>,
#  u'ofglen': <gensim.models.keyedvectors.Vocab at 0x11f7b1910>,
#  u'pleasure': <gensim.models.keyedvectors.Vocab at 0x11ff0f050>,
#  u'pair': <gensim.models.keyedvectors.Vocab at 0x11fefcf90>,
#  u'hide': <gensim.models.keyedvectors.Vocab at 0x11ff16d90>,
#  u'darkness': <gensim.models.keyedvectors.Vocab at 0x11ff24a10>,
#  u'lawn': <gensim.models.keyedvectors.Vocab at 0x11f798890>,
#  u'stupid': <gensim.models.keyedvectors.Vocab at 0x11ff1e250>,
#  u'especially': <gensim.models.keyedvectors.Vocab at 0x11fefcfd0>,
#  u'cloth': <gensim.models.keyedvectors.Vocab at 0x11a8b0f90>,
#  u'considered': <gensim.models.keyedvectors.Vocab at 0x11a8867d0>,
#  u'dream': <gensim.models.keyedvectors.Vocab at 0x11ff24190>,
#  u'professor': <gensim.models.keyedvectors.Vocab at 0x11ff1b050>,
#  u'sometimes': <gensim.models.keyedvectors.Vocab at 0x11f7b1950>,
#  u'cover': <gensim.models.keyedvectors.Vocab at 0x11f7b1990>,
#  u'dog': <gensim.models.keyedvectors.Vocab at 0x11ff287d0>,
#  u'face': <gensim.models.keyedvectors.Vocab at 0x11f7b6e10>,
#  u'looked': <gensim.models.keyedvectors.Vocab at 0x11a8a3890>,
#  u'aunt': <gensim.models.keyedvectors.Vocab at 0x11f7bcf50>,
#  u'talk': <gensim.models.keyedvectors.Vocab at 0x11fefc990>,
#  u'clean': <gensim.models.keyedvectors.Vocab at 0x11fef62d0>,
#  u'occasion': <gensim.models.keyedvectors.Vocab at 0x11ff16250>,
#  u'te': <gensim.models.keyedvectors.Vocab at 0x112158690>,
#  u'usual': <gensim.models.keyedvectors.Vocab at 0x11ff16690>,
#  u'scream': <gensim.models.keyedvectors.Vocab at 0x11ff1b150>,
#  u'fact': <gensim.models.keyedvectors.Vocab at 0x11f7b6e50>,
#  u'saying': <gensim.models.keyedvectors.Vocab at 0x11ff1b510>,
#  u'walking': <gensim.models.keyedvectors.Vocab at 0x11f7988d0>,
#  u'marthas': <gensim.models.keyedvectors.Vocab at 0x11f7b6e90>,
#  u'shot': <gensim.models.keyedvectors.Vocab at 0x11ff1e050>,
#  u'gold': <gensim.models.keyedvectors.Vocab at 0x11f7b19d0>,
#  u'show': <gensim.models.keyedvectors.Vocab at 0x11ff1e090>,
#  u'anyway': <gensim.models.keyedvectors.Vocab at 0x11fef4610>,
#  u'hotel': <gensim.models.keyedvectors.Vocab at 0x11a8b0950>,
#  u'discovered': <gensim.models.keyedvectors.Vocab at 0x11ff24210>,
#  u'bring': <gensim.models.keyedvectors.Vocab at 0x11f7b6ed0>,
#  u'bright': <gensim.models.keyedvectors.Vocab at 0x11f798910>,
#  u'shoe': <gensim.models.keyedvectors.Vocab at 0x11ff1e0d0>,
#  u'bedroom': <gensim.models.keyedvectors.Vocab at 0x11ff177d0>,
#  u'carefully': <gensim.models.keyedvectors.Vocab at 0x11ff0f610>,
#  u'corner': <gensim.models.keyedvectors.Vocab at 0x11ff1e110>,
#  u'chicken': <gensim.models.keyedvectors.Vocab at 0x11a8861d0>,
#  u'fine': <gensim.models.keyedvectors.Vocab at 0x11ff0f650>,
#  u'find': <gensim.models.keyedvectors.Vocab at 0x11ff0f690>,
#  u'handmaid': <gensim.models.keyedvectors.Vocab at 0x11ff16290>,
#  u'ground': <gensim.models.keyedvectors.Vocab at 0x11ff1b350>,
#  u'painted': <gensim.models.keyedvectors.Vocab at 0x11a8a3d10>,
#  u'envy': <gensim.models.keyedvectors.Vocab at 0x11fef4690>,
#  u'pause': <gensim.models.keyedvectors.Vocab at 0x11f7b6f10>,
#  u'stair': <gensim.models.keyedvectors.Vocab at 0x11ff24250>,
#  u'daily': <gensim.models.keyedvectors.Vocab at 0x11fefc310>,
#  u'folded': <gensim.models.keyedvectors.Vocab at 0x11ff28810>,
#  u'cloak': <gensim.models.keyedvectors.Vocab at 0x11f798950>,
#  u'eat': <gensim.models.keyedvectors.Vocab at 0x11fef4cd0>,
#  u'going': <gensim.models.keyedvectors.Vocab at 0x11f798990>,
#  u'tape': <gensim.models.keyedvectors.Vocab at 0x11f7b6f50>,
#  u'pretty': <gensim.models.keyedvectors.Vocab at 0x11fef6310>,
#  u'circle': <gensim.models.keyedvectors.Vocab at 0x11fef6350>,
#  u'gileadean': <gensim.models.keyedvectors.Vocab at 0x11f7989d0>,
#  u'hope': <gensim.models.keyedvectors.Vocab at 0x11f7b6f90>,
#  u'exchanged': <gensim.models.keyedvectors.Vocab at 0x11f7b6fd0>,
#  u'plate': <gensim.models.keyedvectors.Vocab at 0x11ff1bb10>,
#  u'hit': <gensim.models.keyedvectors.Vocab at 0x11fef4190>,
#  u'therefore': <gensim.models.keyedvectors.Vocab at 0x11ff0f6d0>,
#  u'get': <gensim.models.keyedvectors.Vocab at 0x11ff1e1d0>,
#  u'toilet': <gensim.models.keyedvectors.Vocab at 0x11a886f90>,
#  u'familiar': <gensim.models.keyedvectors.Vocab at 0x11f7bc050>,
#  u'hand_lotion': <gensim.models.keyedvectors.Vocab at 0x11a8a3450>,
#  u'stop': <gensim.models.keyedvectors.Vocab at 0x11ff288d0>,
#  u'lucky': <gensim.models.keyedvectors.Vocab at 0x11f7bc090>,
#  u'trees': <gensim.models.keyedvectors.Vocab at 0x11fef6390>,
#  u'pocket': <gensim.models.keyedvectors.Vocab at 0x11ff1b4d0>,
#  u'whistle': <gensim.models.keyedvectors.Vocab at 0x11a8b0b90>,
#  u'cannot': <gensim.models.keyedvectors.Vocab at 0x11ff24290>,
#  u'breast': <gensim.models.keyedvectors.Vocab at 0x11ff0f750>,
#  u'cushion': <gensim.models.keyedvectors.Vocab at 0x11ff1b650>,
#  u'probably': <gensim.models.keyedvectors.Vocab at 0x11fef6490>,
#  u'two_men': <gensim.models.keyedvectors.Vocab at 0x11a886d90>,
#  u'trade': <gensim.models.keyedvectors.Vocab at 0x11f7b14d0>,
#  u'learned': <gensim.models.keyedvectors.Vocab at 0x11ff24a50>,
#  u'sweat': <gensim.models.keyedvectors.Vocab at 0x11a88f190>,
#  u'quiet': <gensim.models.keyedvectors.Vocab at 0x11a886990>,
#  u'gray': <gensim.models.keyedvectors.Vocab at 0x11fef46d0>,
#  u'sleeve': <gensim.models.keyedvectors.Vocab at 0x11f7b1a10>,
#  u'held': <gensim.models.keyedvectors.Vocab at 0x11ff24d90>,
#  u'leather': <gensim.models.keyedvectors.Vocab at 0x11ff242d0>,
#  u'cry': <gensim.models.keyedvectors.Vocab at 0x11f7b1a50>,
#  u'perfume': <gensim.models.keyedvectors.Vocab at 0x11fef6410>,
#  u'bag': <gensim.models.keyedvectors.Vocab at 0x11ff28910>,
#  u'offred': <gensim.models.keyedvectors.Vocab at 0x11f7bcf90>,
#  u'stuff': <gensim.models.keyedvectors.Vocab at 0x11f7bc0d0>,
#  u'common': <gensim.models.keyedvectors.Vocab at 0x11ff0f790>,
#  u'wish': <gensim.models.keyedvectors.Vocab at 0x11fef4710>,
#  u'distant': <gensim.models.keyedvectors.Vocab at 0x11fef4990>,
#  u'river': <gensim.models.keyedvectors.Vocab at 0x11f7b1ad0>,
#  u'husband': <gensim.models.keyedvectors.Vocab at 0x11ff24310>,
#  u'view': <gensim.models.keyedvectors.Vocab at 0x11a8a3ad0>,
#  u'knowing': <gensim.models.keyedvectors.Vocab at 0x11a8a3b10>,
#  u'set': <gensim.models.keyedvectors.Vocab at 0x11f7b1b10>,
#  u'habit': <gensim.models.keyedvectors.Vocab at 0x11ff12790>,
#  u'sex': <gensim.models.keyedvectors.Vocab at 0x11f7b1b50>,
#  u'see': <gensim.models.keyedvectors.Vocab at 0x11f7b1b90>,
#  u'accused': <gensim.models.keyedvectors.Vocab at 0x11fef4c10>,
#  u'college': <gensim.models.keyedvectors.Vocab at 0x11a8868d0>,
#  u'driveway': <gensim.models.keyedvectors.Vocab at 0x11a886750>,
#  u'existence': <gensim.models.keyedvectors.Vocab at 0x11ff0f090>,
#  u'sleeping': <gensim.models.keyedvectors.Vocab at 0x11ff1e550>,
#  u'close': <gensim.models.keyedvectors.Vocab at 0x11fef6450>,
#  u'cold': <gensim.models.keyedvectors.Vocab at 0x11ff17b90>,
#  u'best': <gensim.models.keyedvectors.Vocab at 0x11ff1b810>,
#  u'subject': <gensim.models.keyedvectors.Vocab at 0x11ff28a10>,
#  u'destroyed': <gensim.models.keyedvectors.Vocab at 0x11ff12190>,
#  u'knees': <gensim.models.keyedvectors.Vocab at 0x11a8a3850>,
#  u'wire': <gensim.models.keyedvectors.Vocab at 0x11f7bc110>,
#  u'onto': <gensim.models.keyedvectors.Vocab at 0x11ff12490>,
#  u'temptation': <gensim.models.keyedvectors.Vocab at 0x11ff127d0>,
#  u'mine': <gensim.models.keyedvectors.Vocab at 0x11ff28710>,
#  u'movie': <gensim.models.keyedvectors.Vocab at 0x11f7b1bd0>,
#  u'away': <gensim.models.keyedvectors.Vocab at 0x11f7bcfd0>,
#  u'exchange': <gensim.models.keyedvectors.Vocab at 0x11ff0fe90>,
#  u'please': <gensim.models.keyedvectors.Vocab at 0x11ff0f7d0>,
#  u'kind': <gensim.models.keyedvectors.Vocab at 0x11a8b0990>,
#  u'kneeling': <gensim.models.keyedvectors.Vocab at 0x11a886cd0>,
#  u'case': <gensim.models.keyedvectors.Vocab at 0x11a886b50>,
#  u'state': <gensim.models.keyedvectors.Vocab at 0x11fef4750>,
#  u'fish': <gensim.models.keyedvectors.Vocab at 0x11a886f10>,
#  u'finger': <gensim.models.keyedvectors.Vocab at 0x11ff12810>,
#  u'closed': <gensim.models.keyedvectors.Vocab at 0x11a8a3b50>,
#  u'routine': <gensim.models.keyedvectors.Vocab at 0x11ff16310>,
#  u'drawn': <gensim.models.keyedvectors.Vocab at 0x11ff17050>,
#  u'neither': <gensim.models.keyedvectors.Vocab at 0x11fef4790>,
#  u'reading': <gensim.models.keyedvectors.Vocab at 0x11ff1e350>,
#  u'across': <gensim.models.keyedvectors.Vocab at 0x11ff1e390>,
#  u'rita': <gensim.models.keyedvectors.Vocab at 0x11f7b1c10>,
#  u'supposed': <gensim.models.keyedvectors.Vocab at 0x11ff0f550>,
#  u'available': <gensim.models.keyedvectors.Vocab at 0x11f7b1c50>,
# ...
#  u'among': <gensim.models.keyedvectors.Vocab at 0x11ff1e410>,
#  u'liked': <gensim.models.keyedvectors.Vocab at 0x11fef64d0>,
#  u'words': <gensim.models.keyedvectors.Vocab at 0x11a8a3a10>,
#  u'afterwards': <gensim.models.keyedvectors.Vocab at 0x11a886a10>,
#  u'drunk': <gensim.models.keyedvectors.Vocab at 0x11f7b1d10>,
#  u'color': <gensim.models.keyedvectors.Vocab at 0x11a886a50>,
#  u'sky': <gensim.models.keyedvectors.Vocab at 0x11a8a3ed0>,
#  u'others': <gensim.models.keyedvectors.Vocab at 0x11ff0ff10>,
#  u'period': <gensim.models.keyedvectors.Vocab at 0x11a886a90>,
#  u'whatever': <gensim.models.keyedvectors.Vocab at 0x11fef6510>,
#  u'walk': <gensim.models.keyedvectors.Vocab at 0x11a8a3c90>,
#  u'whisper': <gensim.models.keyedvectors.Vocab at 0x11fef4890>,
#  u'laugh': <gensim.models.keyedvectors.Vocab at 0x11ff16450>,
#  u'church': <gensim.models.keyedvectors.Vocab at 0x11f7b1d50>,
#  u'whispering': <gensim.models.keyedvectors.Vocab at 0x11f7bc190>,
#  u'mattress': <gensim.models.keyedvectors.Vocab at 0x11a8b0590>,
#  u'trust': <gensim.models.keyedvectors.Vocab at 0x11ff12950>,
#  u'speak': <gensim.models.keyedvectors.Vocab at 0x11ff170d0>,
#  u'bastardes_carborundorum': <gensim.models.keyedvectors.Vocab at 0x11ff16490>,
#  u'black_market': <gensim.models.keyedvectors.Vocab at 0x11fefca50>,
#  u'bathroom': <gensim.models.keyedvectors.Vocab at 0x11ff12990>,
#  u'raise': <gensim.models.keyedvectors.Vocab at 0x11a88f110>,
#  u'asks': <gensim.models.keyedvectors.Vocab at 0x11ff28a90>,
#  u'ear': <gensim.models.keyedvectors.Vocab at 0x11a8a3950>,
#  u'damp': <gensim.models.keyedvectors.Vocab at 0x11fef6550>,
#  u'serena_joy': <gensim.models.keyedvectors.Vocab at 0x11f798a90>,
#  u'tiny': <gensim.models.keyedvectors.Vocab at 0x11ff28b10>,
#  u'mark': <gensim.models.keyedvectors.Vocab at 0x11ff1e450>,
#  u'breath': <gensim.models.keyedvectors.Vocab at 0x11f798ad0>,
#  u'secret': <gensim.models.keyedvectors.Vocab at 0x11ff0f890>,
#  u'much': <gensim.models.keyedvectors.Vocab at 0x11ff1b610>,
#  u'slowly': <gensim.models.keyedvectors.Vocab at 0x11fef4850>,
#  u'interest': <gensim.models.keyedvectors.Vocab at 0x11ff28b50>,
#  u'certain': <gensim.models.keyedvectors.Vocab at 0x11f798f10>,
#  u'expected': <gensim.models.keyedvectors.Vocab at 0x11ff12a10>,
#  u'curtain': <gensim.models.keyedvectors.Vocab at 0x11ff164d0>,
#  u'pretending': <gensim.models.keyedvectors.Vocab at 0x11fef63d0>,
#  u'waste': <gensim.models.keyedvectors.Vocab at 0x11f7bc1d0>,
#  u'hardly': <gensim.models.keyedvectors.Vocab at 0x11a886ad0>,
#  u'empty': <gensim.models.keyedvectors.Vocab at 0x11fef6590>,
#  u'box': <gensim.models.keyedvectors.Vocab at 0x11fefc5d0>,
#  u'life': <gensim.models.keyedvectors.Vocab at 0x11ff1b8d0>,
#  u'lived': <gensim.models.keyedvectors.Vocab at 0x11fef65d0>,
#  u'partly': <gensim.models.keyedvectors.Vocab at 0x11fef6610>,
#  u'ghost': <gensim.models.keyedvectors.Vocab at 0x11fef4c90>,
#  u'fire': <gensim.models.keyedvectors.Vocab at 0x11f7b1d90>,
#  u'mind': <gensim.models.keyedvectors.Vocab at 0x11ff286d0>,
#  u'thousand': <gensim.models.keyedvectors.Vocab at 0x11ff1eb10>,
#  u'else': <gensim.models.keyedvectors.Vocab at 0x11fef4d90>,
#  u'sort': <gensim.models.keyedvectors.Vocab at 0x11a8a3310>,
#  u'finished': <gensim.models.keyedvectors.Vocab at 0x11ff16510>,
#  u'lift': <gensim.models.keyedvectors.Vocab at 0x11ff1bdd0>,
#  u'awake': <gensim.models.keyedvectors.Vocab at 0x11f7b1dd0>,
#  u'child': <gensim.models.keyedvectors.Vocab at 0x11ff1b110>,
#  u'catch': <gensim.models.keyedvectors.Vocab at 0x11ff12a50>,
#  u'last': <gensim.models.keyedvectors.Vocab at 0x11a8a3d50>,
#  u'worked': <gensim.models.keyedvectors.Vocab at 0x11ff1b450>,
#  u'pig': <gensim.models.keyedvectors.Vocab at 0x11ff16a50>,
#  u'despite': <gensim.models.keyedvectors.Vocab at 0x11ff12750>,
#  u'former': <gensim.models.keyedvectors.Vocab at 0x11f798b10>,
#  u'present': <gensim.models.keyedvectors.Vocab at 0x11a8a3d90>,
#  u'sound': <gensim.models.keyedvectors.Vocab at 0x11ff1e510>,
#  u'wood': <gensim.models.keyedvectors.Vocab at 0x11a886850>,
#  u'look': <gensim.models.keyedvectors.Vocab at 0x11fef6690>,
#  u'talking': <gensim.models.keyedvectors.Vocab at 0x11ff125d0>,
#  u'straight': <gensim.models.keyedvectors.Vocab at 0x11f7b1e10>,
#  u'air': <gensim.models.keyedvectors.Vocab at 0x11ff17150>,
#  u'rope': <gensim.models.keyedvectors.Vocab at 0x11fef66d0>,
#  u'near': <gensim.models.keyedvectors.Vocab at 0x11ff28b90>,
#  u'suppose': <gensim.models.keyedvectors.Vocab at 0x11ff28bd0>,
#  u'ought': <gensim.models.keyedvectors.Vocab at 0x11fef6710>,
#  u'leaning': <gensim.models.keyedvectors.Vocab at 0x11f7b1e50>,
#  u'voice': <gensim.models.keyedvectors.Vocab at 0x11ff17190>,
#  u'mistake': <gensim.models.keyedvectors.Vocab at 0x11ff171d0>,
#  u'remembering': <gensim.models.keyedvectors.Vocab at 0x11f591710>,
#  u'cane': <gensim.models.keyedvectors.Vocab at 0x11ff28c10>,
#  u'played': <gensim.models.keyedvectors.Vocab at 0x11f5915d0>,
#  u'commander_wife': <gensim.models.keyedvectors.Vocab at 0x11fefc650>,
#  u'blood': <gensim.models.keyedvectors.Vocab at 0x11ff1efd0>,
#  u'thus': <gensim.models.keyedvectors.Vocab at 0x11a8a3e10>,
#  u'commander': <gensim.models.keyedvectors.Vocab at 0x11ff24390>,
#  u'helped': <gensim.models.keyedvectors.Vocab at 0x11ff16550>,
#  u'middle': <gensim.models.keyedvectors.Vocab at 0x11ff1e590>,
#  u'good': <gensim.models.keyedvectors.Vocab at 0x11ff0f110>,
#  u'ready': <gensim.models.keyedvectors.Vocab at 0x11fef6750>,
#  u'partner': <gensim.models.keyedvectors.Vocab at 0x11ff16590>,
#  u'sits': <gensim.models.keyedvectors.Vocab at 0x11f7bc210>,
#  u'seem': <gensim.models.keyedvectors.Vocab at 0x11ff28790>,
#  u'worry': <gensim.models.keyedvectors.Vocab at 0x11ff24410>,
#  u'grown': <gensim.models.keyedvectors.Vocab at 0x11ff28c50>,
#  u'funny': <gensim.models.keyedvectors.Vocab at 0x11f7b1ed0>,
#  u'different': <gensim.models.keyedvectors.Vocab at 0x11ff1e5d0>,
#  u'pas': <gensim.models.keyedvectors.Vocab at 0x11ff1e610>,
#  u'shirt': <gensim.models.keyedvectors.Vocab at 0x11a8b0d90>,
#  u'anymore': <gensim.models.keyedvectors.Vocab at 0x11fef6790>,
#  u'doctor': <gensim.models.keyedvectors.Vocab at 0x11ff1e650>,
#  u'wearing': <gensim.models.keyedvectors.Vocab at 0x11ff28890>,
#  u'things': <gensim.models.keyedvectors.Vocab at 0x11f591b10>,
#  u'make': <gensim.models.keyedvectors.Vocab at 0x11ff28c90>,
#  u'morning': <gensim.models.keyedvectors.Vocab at 0x11ff1e210>,
#  u'bowl': <gensim.models.keyedvectors.Vocab at 0x11f7b1490>,
#  u'cross': <gensim.models.keyedvectors.Vocab at 0x11a8a3e90>,
#  u'beside': <gensim.models.keyedvectors.Vocab at 0x11ff12110>,
#  u'rules': <gensim.models.keyedvectors.Vocab at 0x11ff24610>,
#  u'strange': <gensim.models.keyedvectors.Vocab at 0x11a8b05d0>,
#  u'speech': <gensim.models.keyedvectors.Vocab at 0x11ff1e6d0>,
#  u'belly': <gensim.models.keyedvectors.Vocab at 0x11ff28cd0>,
#  u'corridor': <gensim.models.keyedvectors.Vocab at 0x11ff0f950>,
#  u'underground': <gensim.models.keyedvectors.Vocab at 0x11fef4910>,
#  u'colonies': <gensim.models.keyedvectors.Vocab at 0x11ff28d50>,
#  u'regime': <gensim.models.keyedvectors.Vocab at 0x11ff17650>,
#  u'showing': <gensim.models.keyedvectors.Vocab at 0x11fef6890>,
#  u'day': <gensim.models.keyedvectors.Vocab at 0x11ff0f990>,
#  u'week': <gensim.models.keyedvectors.Vocab at 0x11f7b1610>,
#  u'hallway': <gensim.models.keyedvectors.Vocab at 0x11fef67d0>,
#  u'outside': <gensim.models.keyedvectors.Vocab at 0x11a886910>,
#  u'used': <gensim.models.keyedvectors.Vocab at 0x11fef6810>,
#  u'knitting': <gensim.models.keyedvectors.Vocab at 0x11f7b1f50>,
#  u'breasts': <gensim.models.keyedvectors.Vocab at 0x11a8a3150>,
#  u'drink': <gensim.models.keyedvectors.Vocab at 0x11ff24f50>,
#  u'upon': <gensim.models.keyedvectors.Vocab at 0x11f7bc250>,
#  u'yesterday': <gensim.models.keyedvectors.Vocab at 0x11ff0f9d0>,
#  u'rain': <gensim.models.keyedvectors.Vocab at 0x11ff123d0>,
#  u'hand': <gensim.models.keyedvectors.Vocab at 0x11ff17250>,
#  u'running': <gensim.models.keyedvectors.Vocab at 0x11ff1e710>,
#  u'fruit': <gensim.models.keyedvectors.Vocab at 0x11ff24450>,
#  u'moving': <gensim.models.keyedvectors.Vocab at 0x11a8b0dd0>,
#  u'purpose': <gensim.models.keyedvectors.Vocab at 0x11ff1be90>,
#  u'never': <gensim.models.keyedvectors.Vocab at 0x11fef4fd0>,
#  u'canopy': <gensim.models.keyedvectors.Vocab at 0x11a8a3c10>,
#  u'butter': <gensim.models.keyedvectors.Vocab at 0x11ff28d90>,
#  u'early': <gensim.models.keyedvectors.Vocab at 0x11ff24650>,
#  u'lower': <gensim.models.keyedvectors.Vocab at 0x11a8b0e10>,
#  u'kept': <gensim.models.keyedvectors.Vocab at 0x11ff17290>,
#  u'whose': <gensim.models.keyedvectors.Vocab at 0x11fef4dd0>,
#  u'whispers': <gensim.models.keyedvectors.Vocab at 0x11f7bc390>,
#  u'nevertheless': <gensim.models.keyedvectors.Vocab at 0x11fef60d0>,
#  u'try': <gensim.models.keyedvectors.Vocab at 0x11f7b1690>,
#  u'cheek': <gensim.models.keyedvectors.Vocab at 0x11a8b0e50>,
#  u'well': <gensim.models.keyedvectors.Vocab at 0x11fef4950>,
#  u'center': <gensim.models.keyedvectors.Vocab at 0x11ff165d0>,
#  u'thought': <gensim.models.keyedvectors.Vocab at 0x11ff16610>,
#  u'person': <gensim.models.keyedvectors.Vocab at 0x11f7b1f90>,
#  u'without': <gensim.models.keyedvectors.Vocab at 0x11a886c10>,
#  u'relief': <gensim.models.keyedvectors.Vocab at 0x11a886c50>,
#  u'bottle': <gensim.models.keyedvectors.Vocab at 0x11ff1e750>,
#  u'mother': <gensim.models.keyedvectors.Vocab at 0x11ff12b10>,
#  u'nolite': <gensim.models.keyedvectors.Vocab at 0x11a88f4d0>,
#  u'position': <gensim.models.keyedvectors.Vocab at 0x11ff16650>,
#  u'drawing': <gensim.models.keyedvectors.Vocab at 0x11f7bc290>,
#  u'bodies': <gensim.models.keyedvectors.Vocab at 0x11a886c90>,
#  u'left': <gensim.models.keyedvectors.Vocab at 0x11ff28dd0>,
#  u'summer': <gensim.models.keyedvectors.Vocab at 0x11f798b50>,
#  u'background': <gensim.models.keyedvectors.Vocab at 0x11ff28f10>,
#  u'flesh': <gensim.models.keyedvectors.Vocab at 0x11f7bc2d0>,
#  u'money': <gensim.models.keyedvectors.Vocab at 0x11ff1e790>,
#  u'hands': <gensim.models.keyedvectors.Vocab at 0x11fef4290>,
#  u'white_wing': <gensim.models.keyedvectors.Vocab at 0x11f7bc310>,
#  u'rest': <gensim.models.keyedvectors.Vocab at 0x11f798b90>,
#  u'snow': <gensim.models.keyedvectors.Vocab at 0x11ff12610>,
#  u'front': <gensim.models.keyedvectors.Vocab at 0x11fef42d0>,
#  u'shape': <gensim.models.keyedvectors.Vocab at 0x11ff0fa50>,
#  u'kill': <gensim.models.keyedvectors.Vocab at 0x11f7b1a90>,
#  u'rooms': <gensim.models.keyedvectors.Vocab at 0x11f7bc350>,
#  u'human': <gensim.models.keyedvectors.Vocab at 0x11ff28e10>,
#  u'touch': <gensim.models.keyedvectors.Vocab at 0x11ff24510>,
#  u'yes': <gensim.models.keyedvectors.Vocab at 0x11ff28e50>,
#  u'yet': <gensim.models.keyedvectors.Vocab at 0x11ff28e90>,
#  u'death': <gensim.models.keyedvectors.Vocab at 0x11ff24550>,
#  u'got': <gensim.models.keyedvectors.Vocab at 0x11ff12350>,
#  u'instance': <gensim.models.keyedvectors.Vocab at 0x11fef45d0>,
#  u'thinking': <gensim.models.keyedvectors.Vocab at 0x11ff24590>,
#  u'carborundorum': <gensim.models.keyedvectors.Vocab at 0x11a88f350>,
#  u'danger': <gensim.models.keyedvectors.Vocab at 0x11fef6f50>,
#  u'seems': <gensim.models.keyedvectors.Vocab at 0x11a886d10>,
#  u'except': <gensim.models.keyedvectors.Vocab at 0x11a886d50>,
#  u'hall': <gensim.models.keyedvectors.Vocab at 0x11ff17c90>,
#  u'wall': <gensim.models.keyedvectors.Vocab at 0x11a8a3c50>,
#  u'add': <gensim.models.keyedvectors.Vocab at 0x11ff166d0>,
#  u'spread': <gensim.models.keyedvectors.Vocab at 0x11ff172d0>,
#  u'easy': <gensim.models.keyedvectors.Vocab at 0x11ff17110>,
#  u'wet': <gensim.models.keyedvectors.Vocab at 0x11fef6650>,
#  u'save': <gensim.models.keyedvectors.Vocab at 0x11ff28ed0>,
#  u'hat': <gensim.models.keyedvectors.Vocab at 0x11f591350>,
#  u'surprised': <gensim.models.keyedvectors.Vocab at 0x11f7b1fd0>,
#  u'joke': <gensim.models.keyedvectors.Vocab at 0x11ff16390>,
#  u'real': <gensim.models.keyedvectors.Vocab at 0x11ff245d0>,
#  u'give_away': <gensim.models.keyedvectors.Vocab at 0x11f7b1e90>,
#  u'around': <gensim.models.keyedvectors.Vocab at 0x11f798bd0>,
#  u'read': <gensim.models.keyedvectors.Vocab at 0x11f7b1f10>,
#  u'big': <gensim.models.keyedvectors.Vocab at 0x11ff0fb10>,
#  u'couple': <gensim.models.keyedvectors.Vocab at 0x11f7b6050>,
#  u'possible': <gensim.models.keyedvectors.Vocab at 0x11f591bd0>,
#  u'wives': <gensim.models.keyedvectors.Vocab at 0x11f7b6090>,
#  u'dark': <gensim.models.keyedvectors.Vocab at 0x11f798c10>,
#  u'possibly': <gensim.models.keyedvectors.Vocab at 0x11f591950>,
#  u'game': <gensim.models.keyedvectors.Vocab at 0x11fef68d0>,
#  u'five': <gensim.models.keyedvectors.Vocab at 0x11f7bc3d0>,
#  u'know': <gensim.models.keyedvectors.Vocab at 0x11a8a3f50>,
#  u'birth': <gensim.models.keyedvectors.Vocab at 0x11f591990>,
#  u'desk': <gensim.models.keyedvectors.Vocab at 0x11f7bc410>,
#  u'press': <gensim.models.keyedvectors.Vocab at 0x11a8a3f90>,
#  u'world': <gensim.models.keyedvectors.Vocab at 0x11f798c50>,
#  u'shadow': <gensim.models.keyedvectors.Vocab at 0x11f591510>,
#  u'paint': <gensim.models.keyedvectors.Vocab at 0x11ff0f490>,
#  u'alma': <gensim.models.keyedvectors.Vocab at 0x11ff1ecd0>,
#  u'desire': <gensim.models.keyedvectors.Vocab at 0x11f591650>,
#  u'knock': <gensim.models.keyedvectors.Vocab at 0x11ff0fb50>,
#  u'martha': <gensim.models.keyedvectors.Vocab at 0x11a8a3810>,
#  u'necessary': <gensim.models.keyedvectors.Vocab at 0x11fef4a10>,
#  u'like': <gensim.models.keyedvectors.Vocab at 0x11ff16790>,
#  u'lost': <gensim.models.keyedvectors.Vocab at 0x11fef4a50>,
#  u'moira': <gensim.models.keyedvectors.Vocab at 0x11fef6910>,
#  u'spine': <gensim.models.keyedvectors.Vocab at 0x11f7b6110>,
#  u'sofa': <gensim.models.keyedvectors.Vocab at 0x11ff167d0>,
#  u'ring': <gensim.models.keyedvectors.Vocab at 0x11ff17ed0>,
#  u'commanders': <gensim.models.keyedvectors.Vocab at 0x11a8b0ed0>,
#  u'author': <gensim.models.keyedvectors.Vocab at 0x11a886bd0>,
#  u'heart': <gensim.models.keyedvectors.Vocab at 0x11a8a32d0>,
#  u'remind': <gensim.models.keyedvectors.Vocab at 0x11f591910>,
#  u'continue': <gensim.models.keyedvectors.Vocab at 0x11f7b6150>,
#  u'steps': <gensim.models.keyedvectors.Vocab at 0x11f591e50>,
#  u'nose': <gensim.models.keyedvectors.Vocab at 0x11fef6d90>,
#  u'night': <gensim.models.keyedvectors.Vocab at 0x11ff17310>,
#  u'become': <gensim.models.keyedvectors.Vocab at 0x11f7bc450>,
#  u'fault': <gensim.models.keyedvectors.Vocab at 0x11ff12910>,
#  u'soft': <gensim.models.keyedvectors.Vocab at 0x11ff16810>,
#  u'signal': <gensim.models.keyedvectors.Vocab at 0x11fef6950>,
#  u'two': <gensim.models.keyedvectors.Vocab at 0x11ff1ee50>,
#  u'right': <gensim.models.keyedvectors.Vocab at 0x11f5913d0>,
#  u'old': <gensim.models.keyedvectors.Vocab at 0x11f591ad0>,
#  u'often': <gensim.models.keyedvectors.Vocab at 0x11ff0fb90>,
#  u'crowd': <gensim.models.keyedvectors.Vocab at 0x11f591690>,
#  u'people': <gensim.models.keyedvectors.Vocab at 0x11f5917d0>,
#  u'understand': <gensim.models.keyedvectors.Vocab at 0x11ff0f8d0>,
#  u'nobody': <gensim.models.keyedvectors.Vocab at 0x11ff16190>,
#  u'begin': <gensim.models.keyedvectors.Vocab at 0x11ff24150>,
#  u'alive': <gensim.models.keyedvectors.Vocab at 0x11fef6c10>,
#  u'hair': <gensim.models.keyedvectors.Vocab at 0x11ff16850>,
#  u'lips': <gensim.models.keyedvectors.Vocab at 0x11fef69d0>,
#  u'sure': <gensim.models.keyedvectors.Vocab at 0x11a886790>,
#  u'scrabble': <gensim.models.keyedvectors.Vocab at 0x11ff12bd0>,
#  u'story': <gensim.models.keyedvectors.Vocab at 0x11a8b08d0>,
#  u'sight': <gensim.models.keyedvectors.Vocab at 0x11f7b6190>,
#  u'mirror': <gensim.models.keyedvectors.Vocab at 0x11ff0fc10>,
#  u'dear': <gensim.models.keyedvectors.Vocab at 0x11fefc090>,
#  u'home': <gensim.models.keyedvectors.Vocab at 0x11fef4b90>,
#  u'sit': <gensim.models.keyedvectors.Vocab at 0x11a8a34d0>,
#  u'pale': <gensim.models.keyedvectors.Vocab at 0x11f7b61d0>,
#  u'along_hall': <gensim.models.keyedvectors.Vocab at 0x11a886dd0>,
#  u'leaf': <gensim.models.keyedvectors.Vocab at 0x11a8a3fd0>,
#  u'lead': <gensim.models.keyedvectors.Vocab at 0x11a88f050>,
#  u'purple': <gensim.models.keyedvectors.Vocab at 0x11ff17350>,
#  u'avoid': <gensim.models.keyedvectors.Vocab at 0x11f7bc490>,
#  u'lean': <gensim.models.keyedvectors.Vocab at 0x11a88f090>,
#  ...}

# %%
#Finally time to train the model
w2vmodel.train(sentences, total_examples=w2vmodel.corpus_count, epochs=w2vmodel.iter)

v = w2vmodel.wv.vocab
vocablist = []
for key in v:
    vocablist.append(key)

print vocablist[:25]
# Out:
# 2017-12-14 18:39:16,946 : INFO : training model with 4 workers on 1183 vocabulary and 300 features, using sg=1 hs=0 sample=0.001 negative=5 window=7
# 2017-12-14 18:39:17,345 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2017-12-14 18:39:17,371 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2017-12-14 18:39:17,385 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2017-12-14 18:39:17,390 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2017-12-14 18:39:17,393 : INFO : training on 217395 raw words (132589 effective words) took 0.4s, 306224 effective words/s
# 2017-12-14 18:39:17,397 : WARNING : under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# [u'salvagings', u'forget', u'chain', u'white_cotton', u'forbidden', u'wreath', u'bear', u'yellow', u'month', u'four', u'known', u'sleep', u'ice', u'hanging', u'go', u'chair', u'milk', u'seemed', u'kitchen_table', u'hurry', u'tv', u'elizabeth', u'flash', u'grass', u'young']

# %%
if not os.path.exists("trained"):
    os.makedirs("trained")
w2vmodel.save(os.path.join("trained", "w2vmodel_Atwood.w2v"))

# %%
w2vmodel.wv.most_similar("offred")[:10]
# Out:
# 2017-12-14 18:39:22,481 : INFO : precomputing L2-norms of word weight vectors
# [(u'sofa', 0.999826967716217),
#  (u'sun', 0.999817967414856),
#  (u'carefully', 0.9998103380203247),
#  (u'gray', 0.999808132648468),
#  (u'flower', 0.9998079538345337),
#  (u'system', 0.9998077154159546),
#  (u'mark', 0.9998068809509277),
#  (u'stopped', 0.9998066425323486),
#  (u'become', 0.9998058676719666),
#  (u'middle', 0.9998031258583069)]

# %%
w2vmodel.wv.most_similar("commander")[:10]
# Out:
# [(u'garden', 0.9996933937072754),
#  (u'household', 0.9996857047080994),
#  (u'stool', 0.999683141708374),
#  (u'help', 0.9996800422668457),
#  (u'neck', 0.9996781349182129),
#  (u'watch', 0.9996774792671204),
#  (u'sign', 0.9996774196624756),
#  (u'cane', 0.9996772408485413),
#  (u'marthas', 0.999674916267395),
#  (u'reach', 0.9996746778488159)]

# %%
w2vmodel.wv.most_similar("ofglen")[:10]
# Out:
# [(u'stairs', 0.9997948408126831),
#  (u'new', 0.999788224697113),
#  (u'carefully', 0.9997872114181519),
#  (u'pas', 0.9997871518135071),
#  (u'clean', 0.999786913394928),
#  (u'building', 0.9997867941856384),
#  (u'sheet', 0.9997844099998474),
#  (u'mark', 0.9997844099998474),
#  (u'quickly', 0.9997843503952026),
#  (u'flesh', 0.9997840523719788)]

# %%
w2vmodel.wv.most_similar("nick")[:10]
# Out:
# [(u'lead', 0.999846875667572),
#  (u'reach', 0.9998407959938049),
#  (u'purple', 0.999836802482605),
#  (u'clock', 0.9998335242271423),
#  (u'car', 0.9998334646224976),
#  (u'mark', 0.9998327493667603),
#  (u'cane', 0.9998326897621155),
#  (u'gray', 0.9998321533203125),
#  (u'middle', 0.9998319745063782),
#  (u'catch', 0.9998318552970886)]

# %%
w2vmodel.wv.most_similar("luke")[:10]
# Out:
# [(u'every', 0.9997903108596802),
#  (u'lying', 0.9997903108596802),
#  (u'pregnant', 0.9997866749763489),
#  (u'bathroom', 0.9997862577438354),
#  (u'kept', 0.9997852444648743),
#  (u'school', 0.9997844696044922),
#  (u'told', 0.9997838735580444),
#  (u'together', 0.999783456325531),
#  (u'none', 0.9997833967208862),
#  (u'true', 0.9997811317443848)]

# %%
w2vmodel.wv.most_similar("say")[:10]
# Out:
# [(u'would', 0.9997519254684448),
#  (u'better', 0.999742329120636),
#  (u'things', 0.9997395277023315),
#  (u'done', 0.9997340440750122),
#  (u'used', 0.9997304677963257),
#  (u'well', 0.9997274279594421),
#  (u'know', 0.9997270703315735),
#  (u'think', 0.9997214078903198),
#  (u'bad', 0.9997178912162781),
#  (u'even', 0.9997156858444214)]

# %%
w2vmodel.most_similar_cosmul(
        positive=["commander", "offred"],
        negative=["handmaid"])
# Out:
# [(u'wings', 0.999957799911499),
#  (u'sofa', 0.9999575614929199),
#  (u'outside', 0.9999569654464722),
#  (u'back', 0.9999558329582214),
#  (u'sitting', 0.9999557733535767),
#  (u'sky', 0.999954879283905),
#  (u'feet', 0.9999547600746155),
#  (u'forward', 0.9999547004699707),
#  (u'aunt', 0.999954104423523),
#  (u'keep', 0.9999540448188782)]

# %%
print w2vmodel.most_similar_cosmul(
        positive=["commander", "offred"],
        negative=["ofglen"])

print vocablist[:30]

# %%
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
# %matplotlib inline

w2vmodeltest = w2v.Word2Vec(bigramer[cleaned_sentences],
    sg=0, #algorithm: skip-gram
    seed=seed,#random no. generator
    workers=num_workers, #number of worker threads
    size=100, #dimensions of word vectors
    min_count=50,#minimun occurences words
    window=20,#size of "context" around a word
    sample=downsample, #downsample setting
    negative = 10 #negative sampling 
)

def tsne_plot(model):
    "Creates and TSNE model and plots it"
    labels = []
    tokens = []

    for word in model.wv.vocab:
        tokens.append(model[word])
        labels.append(word)
    
    tsne_model = TSNE(perplexity=40, n_components=2, init='pca', n_iter=2500, random_state=23)
    new_values = tsne_model.fit_transform(tokens)

    x = []
    y = []
    for value in new_values:
        x.append(value[0])
        y.append(value[1])
        
    plt.figure(figsize=(16, 16)) 
    for i in range(len(x)):
        plt.scatter(x[i],y[i])
        plt.annotate(labels[i],
                     xy=(x[i], y[i]),
                     xytext=(5, 2),
                     textcoords='offset points',
                     ha='right',
                     va='bottom')
    plt.show()

tsne_plot(w2vmodeltest)

# %%
from sklearn.decomposition import PCA

# %%
w2vmodel.most_similar_cosmul(
        positive=["Commander", "Offred"],
        negative=["handmaid"])
def nearest_similarity_cosmul(start1, end1, end2):
    similarities = w2vmodel.most_similar_cosmul(
        positive=[end2, start1],
        negative=[end1]
    )
    start2 = similarities[0][0]
    print("{start1} is related to {end1}, as {start2} is related to {end2}".format(**locals()))
    return start2

# %%
thrones2vec = w2v.Word2Vec.load(os.path.join("trained", "thrones2vec.w2v"))
tsne = sklearn.manifold.TSNE(n_components=2, random_state=0)
all_word_vectors_matrix = thrones2vec.syn0
all_word_vectors_matrix_2d = tsne.fit_transform(all_word_vectors_matrix)

# %%
'''exclude = set(string.punctuation) 
lemma = WordNetLemmatizer()

def clean(doc):
    stop_free = " ".join([i for i in doc.lower().split() if i not in stop])
    punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
    normalized = " ".join(lemma.lemmatize(word) for word in stop_free.split())
    return normalized

#raw_sentences_cleaned = [clean(s) for s in raw_sentences]

#transform the sentence in a list
def sentence_to_wordlist(raw):
    clean = re.sub("[^a-zA-Z]"," ", raw)
    words = clean.split()
    return words
'''for s in raw_sentences_cleaned:
    if len(s) > 0:
        sentences.append(sentence_to_wordlist(s))
'''
#the length of sentence stays the same as len(raw_sentence)
if len(sentences) == len(raw_sentences):
    print True
# Out:
# [u'window', u'partly', u'open', u'it', u'open', u'partly', u'the', u'air', u'come', u'make', u'curtain', u'move']
# True
# [raw sentence]: When the window is partly open—it only opens partly—the air can come in and make the curtains move.
# [with stopwords removed]: window partly open—it open partly—the air come make curtain move.
# [transform the sentence in a list]: [u'window', u'partly', u'open', u'it', u'open', u'partly', u'the', u'air', u'come', u'make', u'curtain', u'move']
